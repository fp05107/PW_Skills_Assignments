# %%
# Corpus (C) -> All the words in the data
# Vocabulary (V) -> All the unique words in the data
# Document (D) -> One document in the dataset
# Word (W) -> Normal word in any document

# %%
# Converting Text to number
#  OHE (One Hot Encoding)
# Bag of Words
# N Grams
# Tf-idf
