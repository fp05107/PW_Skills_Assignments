# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.221  Python-3.13.7 torch-2.9.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Setup complete  (12 CPUs, 15.7 GB RAM, 69.4/125.6 GB disk)

# %%
import cv2
