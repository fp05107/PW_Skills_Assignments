# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO("yolo11n.pt")

# %%
results = model('D:\PWSkills\PW_Skills_Assignments\Milestone_4_DeepLearning\week_6\sample_dog_cat.jpg')
# results = model.predict(source="Milestone_4_DeepLearning\week_6\sample_dog_cat.jpg", show=True, conf=0.5)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\prami\AppData\Local\Temp\ipykernel_36988\1944506960.py:1: SyntaxWarning: invalid escape sequence '\P'
#   results = model('D:\PWSkills\PW_Skills_Assignments\Milestone_4_DeepLearning\week_6\sample_dog_cat.jpg')
# image 1/1 D:\PWSkills\PW_Skills_Assignments\Milestone_4_DeepLearning\week_6\sample_dog_cat.jpg: 352x640 1 cat, 1 dog, 157.4ms
# Speed: 38.8ms preprocess, 157.4ms inference, 19.6ms postprocess per image at shape (1, 3, 352, 640)

# %%
results[0].save(filename='output.jpg')
# Out:
# 'output.jpg'

# %%
img = cv2.imread('output.jpg')
cv2.imshow("Object Detection Result", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
