# %% [markdown]
# How would you implement Simple Linear Regression in Python using Scikit-learn?
# [Data Science, Data Analyst], [Paytm, Flipkart, Meesho], 3
# Write a Python code to train a Simple Linear Regression model using a small dataset.
#
# How can you use Python’s statsmodels library to implement Simple Linear Regression?
#
# What are the steps to preprocess data before applying Simple Linear Regression in Python?
#
# How would you implement Multiple Linear Regression in Python using Scikit-learn?
#
# Explain how to interpret the coefficients in a Multiple Linear Regression model implemented in Python.
#
# How would you implement feature selection in a Multiple Linear Regression model using Python?
# [Data Science, Machine Learning Engineer], [Flipkart, Google, Razorpay], 3
# Write a Python code to evaluate the performance of a Multiple Linear Regression model using cross-validation.
#
# What is model pickling, and why is it used in Machine Learning?
# [Data Science, Data Analyst], [Meesho, Razorpay, Flipkart], 3
# Explain how to save and load a machine learning model using pickling in Python.
# [Data Scientist, Machine Learning Engineer], [Google, Paytm, Swiggy], 2
# How would you implement Polynomial Regression in Python using Scikit-learn?
# [Data Science, Data Analyst], [Flipkart], 3
# What are the challenges in implementing Polynomial Regression for higher-degree polynomials?
# [Machine Learning Engineer], [Swiggy, Myntra], 2
# What is multicollinearity, and why is it problematic in regression models?
#
# How does multicollinearity affect the interpretation of regression coefficients?
#
# What are the common methods for detecting multicollinearity in a dataset?
# [Data Scientist, Business Analyst], [Amazon, Microsoft, Paytm], 2
# Explain the Variance Inflation Factor (VIF) and how it helps to detect multicollinearity.
# [Machine Learning Engineer], [Flipkart, Myntra], 2
# How would you detect multicollinearity in a dataset using Python?
# [Data Science, Machine Learning Engineer], [Swiggy, Flipkart, Google], 3
# Write a Python code snippet to calculate the Variance Inflation Factor (VIF) for a regression model.
#
# What steps would you take to reduce multicollinearity in a regression model using Python?

# %% [markdown]
# Interview Questions
# What is Simple Linear Regression, and how is it used in predictive modeling?
# [Data Science, Data Analyst], [Flipkart], 3
# Explain the mathematical equation of Simple Linear Regression.
# [Machine Learning Engineer, Data Scientist], [Zomato, Razorpay], 3
# What is the significance of the slope and intercept in the linear regression equation?
#
# How would you visualize the relationship between variables using a linear regression model?
#
# What assumptions must hold true for Simple Linear Regression to work effectively?
# [Data Science, Machine Learning Engineer], [Meesho, PayPal], 3
# What are the limitations of using Simple Linear Regression for prediction?
#
# Explain how outliers can affect the performance of a Simple Linear Regression model.
#
# How would you evaluate the goodness of fit for a Simple Linear Regression model?
# [Data Scientist], [Flipkart, Razorpay, Microsoft], 2
# What is the least-squares method in Simple Linear Regression?
# [Data Science, Machine Learning Engineer], [Swiggy, Google, Walmart], 3
# How do you interpret the coefficients obtained from a Simple Linear Regression model?
# [Data Analyst, Machine Learning Engineer], [Meesho, Amazon, Microsoft], 3
# Explain multicollinearity and how it can impact regression models.
#
# How can you test the residuals to ensure that the assumptions of linear regression hold?
# [Data Science, Business Analyst], [Flipkart], 2
# What is the difference between Simple Linear Regression and Multiple Linear Regression?
# [Data Science, Data Analyst], [Swiggy, Google, Paytm], 3
# Explain how feature selection is important in Multiple Linear Regression models.
#
# What are the assumptions underlying Multiple Linear Regression?
#
# What techniques can be used to handle multicollinearity in Multiple Linear Regression?
# [Machine Learning Engineer], [Google, Amazon, Myntra], 2
# How do you interpret the coefficients in a Multiple Linear Regression model?
# [Data Science, Data Analyst], [Paytm, Flipkart, Swiggy], 3
# What does the p-value indicate in the context of feature importance in regression models?
# [Data Scientist], [Razorpay, Walmart, Google], 2
# What is the significance of adjusted R-squared in Multiple Linear Regression?
#
# How would you rank features based on importance in a Multiple Linear Regression model?
#
# What is Polynomial Regression, and how does it extend Simple Linear Regression?
# [Data Science, Machine Learning Engineer], [Flipkart, Google, Razorpay], 3
# Explain the main difference between Linear and Polynomial Regression.
# [Data Scientist], [Paytm, Myntra, Swiggy], 2
# What are the challenges of using Polynomial Regression for high-degree polynomials?
#
# How would you choose the degree of the polynomial in a Polynomial Regression model?
# [Machine Learning Engineer], [Google, Razorpay, Amazon], 2
# What is R-squared, and what does it indicate in a regression model?
# [Data Science, Data Analyst], [Meesho, Flipkart, Zomato], 3
# Explain the difference between R-squared and adjusted R-squared.
# [Data Science, Business Analyst], [Swiggy, Amazon, Razorpay], 2
# Can R-squared be negative, and if so, under what circumstances?
#
# Why is adjusted R-squared preferred when comparing models with different numbers of predictors?
# [Data Scientist], [Flipkart, Walmart], 2
# What are MSE, MAE, and RMSE, and how are they used to evaluate regression models?
# [Data Science, Data Analyst], [Swiggy, Paytm, Flipkart], 3
# How do MSE, MAE, and RMSE differ in terms of their sensitivity to outliers?
# [Machine Learning Engineer], [Myntra, Zomato], 3
# Which of the three—MSE, MAE, or RMSE—is most commonly used, and why?
#
# How would you interpret a low RMSE but high MAE for a regression model?
# [Data Scientist], [Amazon, Flipkart, PayPal], 2
# What are the key assumptions that must hold true for Linear Regression?
# [Data Science, Data Analyst], [Meesho], 3
# Explain the linearity and homoscedasticity assumptions in the context of Linear Regression.
# [Machine Learning Engineer], [Zomato], 3
# How would you check for multicollinearity in a Linear Regression model?
#
# What diagnostic plots would you use to verify the assumptions of Linear Regression?
# [Data Scientist], [Razorpay, Paytm, Amazon], 2
# What is an ML pipeline, and why is it important for machine learning workflows?
# [Data Science, Machine Learning Engineer], [Flipkart, Meesho, Google], 3
# How would you build an end-to-end Machine Learning pipeline in Python?
# [Data Scientist, Data Analyst], [Swiggy, Razorpay, Flipkart], 2
# What are the key components of an ML pipeline, and how do they interact?
#
# Explain how you can use Scikit-learn to create an ML pipeline.
