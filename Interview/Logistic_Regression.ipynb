# %% [markdown]
# What is regularization in regression, and why is it important?
# [Data Science, Data Analyst], [Google, Swiggy, Paytm], 3
#
# Explain the difference between L1 and L2 regularization.
# [Machine Learning Engineer, Data Scientist], [Microsoft, Flipkart], 3
#
# How does regularization help prevent overfitting in regression models?
# [Data Science], [Amazon, Myntra], 2
#
# What is the regularization parameter in Ridge and Lasso regression, and how does it affect the model?
# What are Lasso, Ridge, and Elastic Net regression techniques?
# [Data Science, Machine Learning Engineer], [Flipkart, Zomato, Paytm], 3
#
# Explain the differences between Lasso and Ridge regression.
# [Data Analyst, Data Scientist], [Swiggy, Amazon], 3
#
# How does Elastic Net combine the features of Lasso and Ridge regression?
#
# When would you prefer using Elastic Net over Lasso or Ridge regression?
#
# What is cross-validation, and why is it important in model evaluation?
#
# Explain the concept of hyperparameter tuning and its significance.
# [Data Scientist, Data Analyst], [Amazon, Flipkart, Zomato], 3
#
# What are some common methods for performing hyperparameter tuning?
# [Data Scientist], [Meesho, Myntra], 2
#
# How would you implement k-fold cross-validation in Python using Scikit-learn?
#
# How would you implement Lasso regression in Python using Scikit-learn?
# [Data Science, Data Analyst], [Flipkart, Paytm, Swiggy], 3
#
# Write Python code to perform Ridge regression on a given dataset.
# [Data Scientist], [Amazon, Meesho], 2
#
# Explain how to use Elastic Net regression in Python and when to apply it.
# [Machine Learning Engineer], [Google, Myntra], 2
#
# What is Logistic Regression, and how is it different from Linear Regression?
#
# Explain the concept of the logistic function and its role in Logistic Regression.
#
# What are the assumptions of Logistic Regression?
#
# How would you interpret the coefficients in a Logistic Regression model?
# [Data Scientist], [Microsoft, Swiggy], 2
#
# How does regularization improve the performance of a Logistic Regression model?
#
# What are the differences between L1 and L2 regularization in the context of Logistic Regression?
# [Data Analyst, Data Scientist], [Amazon, Meesho], 2
#
# How would you implement regularization in Logistic Regression using Python?
#
# What are the common metrics used to evaluate classification models?
#
# Explain the concepts of precision, recall, and F1-score.
# [Data Scientist], [Amazon, Swiggy], 3
#
# How would you use ROC and AUC to evaluate a classification model?
#
# What is the confusion matrix, and how is it used in model evaluation?
#
# How would you implement Logistic Regression in Python using Scikit-learn?
# [Data Science, Data Analyst], [Flipkart, Paytm, Swiggy], 3
#
# Write a Python code snippet to train and evaluate a Logistic Regression model.
#
# Explain how to preprocess data before applying Logistic Regression in Python.
# [Data Scientist], [Meesho, Zomato], 2
#
# What techniques would you use to handle class imbalance in Logistic Regression?
#
# How would you perform hyperparameter tuning for a Logistic Regression model in Python?
# [Data Science, Machine Learning Engineer], [Swiggy, Google, Myntra], 3
#
# What hyperparameters are commonly tuned in Logistic Regression models?
# [Data Scientist], [Amazon, Razorpay], 2
#
# What are the differences between binary and multiclass classification?
# [Data Science, Machine Learning Engineer], [Flipkart, Zomato, Swiggy], 3
#
# How would you handle a multiclass classification problem using Logistic Regression?
# [Data Scientist], [Google, Meesho], 2
#
# How would you implement a multiclass classification problem in Python using Scikit-learn?
# [Data Science, Data Analyst], [Amazon, Flipkart, Swiggy], 3
#
# Write Python code to evaluate the performance of a multiclass classification model.
# [Machine Learning Engineer], [Google, Myntra], 2
#
# Write a Python code snippet to perform multiclass classification on the Iris dataset using Scikit-learn.
# [Data Scientist], [Amazon, Zomato], 2
