# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

X, y = make_regression(n_samples=1000, n_features=10, noise=0.1, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train.shape
# Out:
# (800, 10)

# %%
X_test.shape
# Out:
# (200, 10)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
lr = LinearRegression()
dtr = DecisionTreeRegressor()
svr = SVR(kernel='linear')

# %%
from sklearn.ensemble import VotingRegressor

# %%
model = VotingRegressor(estimators=[('lr', lr), ('dtr', dtr), ('svr', svr)])

# %%
model
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('dtr', DecisionTreeRegressor()),
#                             ('svr', SVR(kernel='linear'))])

# %%
model.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('dtr', DecisionTreeRegressor()),
#                             ('svr', SVR(kernel='linear'))])

# %%
model.predict(X_test)
# Out:
# array([  51.18729043,   40.84457857, -165.4724235 ,  -41.48319849,
#         503.07435753,  310.04010346,   45.5226995 ,  -54.52450392,
#        -106.23432287,  -66.20891468, -100.76669527,   48.29758272,
#         -50.14067936, -143.26542553, -311.55125961, -136.89062517,
#        -288.00715565, -163.33857005,  -29.35579152, -188.7015632 ,
#         -68.18178184, -130.5695584 ,  302.53249562, -155.07788943,
#          81.43984705,  187.04567054,  237.17596557,   58.05584608,
#         -66.79627324,  112.84731007,   71.57114458,  245.5369679 ,
#         133.77866601,  273.59571139,  121.53350892,  102.45859897,
#          46.77523303, -369.14513154, -187.87662545,  -83.05983246,
#          47.44785859, -100.667716  ,  108.20962995, -132.66115906,
#          82.36148825,   30.15684664,  185.41636073, -121.92938931,
#         162.76042005, -300.48967015,  230.33434243,  364.42615339,
#        -221.1516962 ,   77.88087229,  -47.72019561,  101.2045309 ,
#         184.32945339,   86.87200653,   41.42911966,   91.9798698 ,
#          53.50231918, -436.06225197,  405.95412225,  170.27915411,
#          21.65276553, -171.72289606,  -69.05480307,    1.97952709,
#         -68.33857787,  159.0645922 ,  464.83715014,   54.60997512,
#         -31.1775236 ,  -75.01820412,  155.47217983, -158.66843472,
#         -52.88845444,   40.45413599,    3.20073129,    9.65085909,
#         -94.99963411,  164.67863507, -113.86583718,   53.29944766,
#        -111.20437273,  177.91151267,   32.40943486, -112.48844982,
#          19.69651588,  -89.94535947, -251.37325467, -216.99899892,
#         -36.06639758,  157.82637301,  141.88872106,   53.04872133,
#         341.19264995,  -93.84858945,  107.99483854, -119.46479243,
#        -128.9522666 ,  210.59622711,  117.66536467,  -15.51023812,
#        -291.0677683 ,  159.11133259,   -2.21159736,  -74.5509121 ,
#          20.71095452,   75.17261449, -177.36843463,  -79.07824222,
#        -152.87587564,  -24.06367463,  407.49699524,   18.91499162,
#        -157.01788262,   70.48644564, -187.97591778, -197.82399577,
#        -129.02969277,  190.87594591, -101.72605388,  187.09982591,
#        -182.77736005,  115.05165531, -355.88190147,  -83.74877475,
#         214.59366005, -146.9329153 ,   14.25733168,   84.02423216,
#         104.61132822, -302.34699391,  -34.75427426,   25.07135473,
#         102.74123257, -200.39940122,   88.29617175,  127.24178059,
#          92.51864326,  199.12016869,  347.58389839,  207.64961712,
#        -103.81816147, -156.45704349,  192.95102871,   56.32574965,
#          79.70131368,  224.14407248,  282.43717021,  177.9201629 ,
#          -0.87335534,  -98.93874057,  -66.09183522,  156.40669637,
#          71.04124069,   69.44792678, -120.10370785, -335.93058046,
#         348.18068899,  -38.43797022, -351.10372396, -113.06440872,
#         -83.30842533, -138.19890608,  -26.72340908,  -24.91112911,
#        -192.28068543,  128.15603057, -209.05001755,  -22.35245826,
#         -92.84799017,   18.59318821,  -85.19014644, -115.41136942,
#         -89.53583317,  125.66533675,  -33.34044559,  -44.6732423 ,
#          -3.45906731,  290.82517927,  175.87200209,   12.20594816,
#          18.35112184, -210.09526035,   29.16125192,  -25.47997581,
#         208.64110296, -161.00682179,  248.22667478,   38.87300985,
#         148.6292996 ,    7.60930181,   41.81339612,   56.59831025,
#         106.64515914,  329.49133621, -173.15505645, -102.82565856])
