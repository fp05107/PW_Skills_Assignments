# %%
import re
import nltk
import string
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
train = pd.read_csv('train_E6oV3lV.csv')
test = pd.read_csv('test_tweets_anuFYb8.csv')

# %%
train
# Out:
#           id  label  \
# 0          1      0
# 1          2      0
# 2          3      0
# 3          4      0
# 4          5      0
# ...      ...    ...
# 31957  31958      0
# 31958  31959      0
# 31959  31960      0
# 31960  31961      1
# 31961  31962      0
#
#                                                                                                                                      tweet
# 0                                    @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1               @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                                      bihday your majesty
# 3                                                   #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                                   factsguide: society now    #motivation
# ...                                                                                                                                    ...
# 31957                                                                 ate @user isz that youuu?ðððððððððâ¤ï¸
# 31958    to see nina turner on the airwaves trying to wrap herself in the mantle of a genuine hero like shirley chisolm. #shame #imwithher
# 31959                                                                      listening to sad songs on a monday morning otw to work is sad
# 31960                                                                  @user #sikh #temple vandalised in in #calgary, #wso condemns  act
# 31961                                                                                                     thank you @user for you follow
#
# [31962 rows x 3 columns]

# %%
train.head()
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                                                                         tweet
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation

# %%
# Text Pre processing
# Data Inspection
# Data cleaning

# %%
train.label.unique()
# Out:
# array([0, 1])

# %%
train[train['label'] == 0].head(10)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
# 5   6      0
# 6   7      0
# 7   8      0
# 8   9      0
# 9  10      0
#
#                                                                                                                                              tweet
# 0                                            @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1                       @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                                              bihday your majesty
# 3                                                           #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                                           factsguide: society now    #motivation
# 5                             [2/2] huge fan fare and big talking before they leave. chaos and pay disputes when they get there. #allshowandnogo
# 6                                                                        @user camping tomorrow @user @user @user @user @user @user @user dannyâ¦
# 7  the next school year is the year for exams.ð¯ can't think about that ð­ #school #exams   #hate #imagine #actorslife #revolutionschool #girl
# 8                                                          we won!!! love the land!!! #allin #cavs #champions #cleveland #clevelandcavaliers  â¦
# 9                                                                                                @user @user welcome here !  i'm   it's so #gr8 !

# %%
train[train['label'] == 1].head(10)
# Out:
#       id  label  \
# 13    14      1
# 14    15      1
# 17    18      1
# 23    24      1
# 34    35      1
# 56    57      1
# 68    69      1
# 77    78      1
# 82    83      1
# 111  112      1
#
#                                                                                                                                  tweet
# 13                                                          @user #cnn calls #michigan middle school 'build the wall' chant '' #tcot
# 14                               no comment!  in #australia   #opkillingbay #seashepherd #helpcovedolphins #thecove  #helpcovedolphins
# 17                                                                                                              retweet if you agree!
# 23                                                                                     @user @user lumpy says i am a . prove it lumpy.
# 34                            it's unbelievable that in the 21st century we'd need something like this. again. #neverump  #xenophobia
# 56                                                                                             @user lets fight against  #love #peace
# 68                      ð©the white establishment can't have blk folx running around loving themselves and promoting our greatness
# 77                                             @user hey, white people: you can call people 'white' by @user  #race  #identity #medâ¦
# 82                                                       how the #altright uses  &amp; insecurity to lure men into #whitesupremacy
# 111  @user i'm not interested in a #linguistics that doesn't address #race &amp; . racism is about #power. #raciolinguistics bringsâ¦

# %%
train.shape
# Out:
# (31962, 3)

# %%
test.shape
# Out:
# (17197, 2)

# %%
train.label.value_counts()
# Out:
# label
# 0    29720
# 1     2242
# Name: count, dtype: int64

# %%
# Imbalanced Classification
length_train = train['tweet'].str.len()
length_test = test['tweet'].str.len()
plt.hist(length_train, bins=20, label="train_tweets")
plt.hist(length_test, bins=20, label="test_tweets")
plt.legend()
plt.show()

# %%
combi = pd.concat([train, test], ignore_index=True)

# %%
combi
# Out:
#           id  label  \
# 0          1    0.0
# 1          2    0.0
# 2          3    0.0
# 3          4    0.0
# 4          5    0.0
# ...      ...    ...
# 49154  49155    NaN
# 49155  49156    NaN
# 49156  49157    NaN
# 49157  49158    NaN
# 49158  49159    NaN
#
#                                                                                                                                                    tweet
# 0                                                  @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1                             @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                                                    bihday your majesty
# 3                                                                 #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                                                 factsguide: society now    #motivation
# ...                                                                                                                                                  ...
# 49154                                       thought factory: left-right polarisation! #trump #uselections2016 #leadership #politics  #brexit #blm &gt;3
# 49155                                                   feeling like a mermaid ð #hairflip #neverready #formal #wedding #gown #dresses #mermaid  â¦
# 49156  #hillary #campaigned today in #ohio((omg)) &amp; used words like "assets&amp;liability" never once did #clinton say thee(word) #radicalization
# 49157                                           happy, at work conference: right mindset leads to culture-of-development organizations    #work #mindset
# 49158                                                                                   my   song "so glad" free download!  #shoegaze #newmusic #newsong
#
# [49159 rows x 3 columns]

# %%
combi.shape
# Out:
# (49159, 3)

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
    return input_txt

# %%
combi['tidy_tweet'] = np.vectorize(remove_pattern)(combi['tweet'], "@[\w]*")
combi.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\prami\AppData\Local\Temp\ipykernel_1232\288800157.py:1: SyntaxWarning: invalid escape sequence '\w'
#   combi['tidy_tweet'] = np.vectorize(remove_pattern)(combi['tweet'], "@[\w]*")
#    id  label  \
# 0   1    0.0
# 1   2    0.0
# 2   3    0.0
# 3   4    0.0
# 4   5    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation
#
#                                                                                                          tidy_tweet
# 0                   when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1    thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                               bihday your majesty
# 3                            #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                            factsguide: society now    #motivation

# %%
combi['tidy_tweet'] = combi['tidy_tweet'].str.replace("[^a-zA-Z#]", " ")

# %%
combi.head()
# Out:
#    id  label  \
# 0   1    0.0
# 1   2    0.0
# 2   3    0.0
# 3   4    0.0
# 4   5    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation
#
#                                                                                                          tidy_tweet
# 0                   when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1    thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                               bihday your majesty
# 3                            #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                            factsguide: society now    #motivation

# %%
combi['tidy_tweet'] = combi['tidy_tweet'].apply(lambda x: ' '.join([w for w in x.split() if len(w) > 3]))

# %%
combi.head()
# Out:
#    id  label  \
# 0   1    0.0
# 1   2    0.0
# 2   3    0.0
# 3   4    0.0
# 4   5    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation
#
#                                                                                        tidy_tweet
# 0                             when father dysfunctional selfish drags kids into dysfunction. #run
# 1  thanks #lyft credit can't cause they don't offer wheelchair vans pdx. #disapointed #getthanked
# 2                                                                             bihday your majesty
# 3                               #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# 4                                                                 factsguide: society #motivation

# %%
tokenized_tweet = combi['tidy_tweet'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0                                   [when, father, dysfunctional, selfish, drags, kids, into, dysfunction., #run]
# 1    [thanks, #lyft, credit, can't, cause, they, don't, offer, wheelchair, vans, pdx., #disapointed, #getthanked]
# 2                                                                                         [bihday, your, majesty]
# 3                                      [#model, love, take, with, time, urð±!!!, ðððð, ð¦ð¦ð¦]
# 4                                                                             [factsguide:, society, #motivation]
# Name: tidy_tweet, dtype: object

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()
tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x])

# %%
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])
combi['tidy_tweet'] = tokenized_tweet

# %%
tokenized_tweet
# Out:
# 0                                                                 when father dysfunct selfish drag kid into dysfunction. #run
# 1                                      thank #lyft credit can't caus they don't offer wheelchair van pdx. #disapoint #getthank
# 2                                                                                                          bihday your majesti
# 3                                                            #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# 4                                                                                                   factsguide: societi #motiv
#                                                                  ...
# 49154                  thought factory: left-right polarisation! #trump #uselections2016 #leadership #polit #brexit #blm &gt;3
# 49155                                          feel like mermaid ð #hairflip #neverreadi #formal #wed #gown #dress #mermaid
# 49156    #hillari #campaign today #ohio((omg)) &amp; use word like "assets&amp;liability" never onc #clinton thee(word) #radic
# 49157                                       happy, work conference: right mindset lead culture-of-develop organ #work #mindset
# 49158                                                                      song glad" free download! #shoegaz #newmus #newsong
# Name: tidy_tweet, Length: 49159, dtype: object

# %%
combi['tidy_tweet']
# Out:
# 0                                                                 when father dysfunct selfish drag kid into dysfunction. #run
# 1                                      thank #lyft credit can't caus they don't offer wheelchair van pdx. #disapoint #getthank
# 2                                                                                                          bihday your majesti
# 3                                                            #model love take with time urð±!!! ðððð ð¦ð¦ð¦
# 4                                                                                                   factsguide: societi #motiv
#                                                                  ...
# 49154                  thought factory: left-right polarisation! #trump #uselections2016 #leadership #polit #brexit #blm &gt;3
# 49155                                          feel like mermaid ð #hairflip #neverreadi #formal #wed #gown #dress #mermaid
# 49156    #hillari #campaign today #ohio((omg)) &amp; use word like "assets&amp;liability" never onc #clinton thee(word) #radic
# 49157                                       happy, work conference: right mindset lead culture-of-develop organ #work #mindset
# 49158                                                                      song glad" free download! #shoegaz #newmus #newsong
# Name: tidy_tweet, Length: 49159, dtype: object

# %%
all_words = ' '.join([text for text in combi['tidy_tweet']])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
normal_words = ' '.join([text for text in combi['tidy_tweet'][combi['label'] == 0]])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
negative_words = ' '.join([text for text in combi['tidy_tweet'][combi['label'] == 1]])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(negative_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
def hashtag_extract(x):
    hashtags = []
    for i in x:
        ht = re.findall(r"#(\w+)", i)
        hashtags.append(ht)
    return hashtags

# %%
# Extracting hashtags from non racist/sexiest tweets
HT_regular = hashtag_extract(combi['tidy_tweet'][combi['label'] == 0])
# Extracting hashtags from racist/sexiest twwets
HT_negative = hashtag_extract(combi['tidy_tweet'][combi['label'] == 1])

# %%
HT_negative
# Out:
# [['cnn', 'michigan', 'tcot'],
#  ['australia',
#   'opkillingbay',
#   'seashepherd',
#   'helpcovedolphin',
#   'thecov',
#   'helpcovedolphin'],
#  [],
#  [],
#  ['neverump', 'xenophobia'],
#  ['love', 'peac'],
#  [],
#  ['race', 'ident', 'medâ'],
#  ['altright', 'whitesupremaci'],
#  ['linguist', 'race', 'power', 'raciolinguist'],
#  ['brexit'],
#  ['peopl', 'trump', 'republican'],
#  ['michelleobama'],
#  ['knick', 'golfâ'],
#  ['jewishsupremacist'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['trash', 'hate'],
#  [],
#  ['â'],
#  ['stereotyp', 'prejudic', 'hope', 'hate', 'conflictâ'],
#  ['pol', 'bluelivesmatt', 'draintheswamp', 'ferguson'],
#  ['2016'],
#  ['antisemit', 'hocoschool', 'columbiamd', 'hocomd'],
#  ['nazi', 'hatred', 'bigotri'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['p21', 'fyi', 'tcot'],
#  ['topoli'],
#  ['blacklivesmatt'],
#  ['ushistori', 'eugen'],
#  ['biher', 'bigotri', 'altright', 'potu', 'theresist'],
#  ['crime', 'officerâ'],
#  [],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  ['allahsoil'],
#  [],
#  ['prais', 'cleveland', 'rnc', 'white', 'tamirric', 'rip'],
#  ['bigot'],
#  [],
#  ['blacklivesmatt'],
#  ['feminismiscanc', 'feminismisterror', 'feminismmuktbharat', 'malevot'],
#  [],
#  ['prowar', 'anti', 'islamic', 'homophobic', 'rapist', 'hypocrit'],
#  [],
#  ['latesnew'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['trump', 'dumptrump'],
#  ['lifelesson', 'blogpost', 'whitepeopl', 'respectâ'],
#  [],
#  ['fakenewsal'],
#  ['hateâ'],
#  ['trump', 'hate', 'putin', 'trump'],
#  [],
#  [],
#  ['starspangledbann', 'slaveri', 'apaheid', 'usa'],
#  ['social', 'media', 'aand'],
#  ['eod'],
#  ['trump', 'vile', 'bigot', 'hi', 'surrog', 'carlpaladino', 'endhateâ'],
#  ['allahsoil'],
#  ['discrimin'],
#  ['endthen'],
#  ['misogyny', 'homophobia', 'bigotri'],
#  [],
#  [],
#  ['rushlimbaugh'],
#  [],
#  ['trumpusa', 'homophob', 'misogynist'],
#  ['sjw'],
#  ['hope', 'newyear', 'endof2016', 'tedtalk', 'tedatibm'],
#  ['cspan'],
#  ['peopl', 'trump', 'republican'],
#  ['opinion', 'degrad', 'discrimin', 'violenc', 'stoprac'],
#  ['allahsoil',
#   'isi',
#   'islam',
#   '2016in4world',
#   '2016in4word',
#   'terrorist',
#   'gwot'],
#  ['tuckercarlson'],
#  [],
#  ['oppress', 'oppressors', 'privileg'],
#  ['space'],
#  [],
#  ['ivankatrump', 'fake', 'adamsaleh', 'raâ'],
#  ['zionazi'],
#  [],
#  ['lbgt'],
#  ['trump', 'barackobama', 'michelleobama'],
#  ['quebec', 'humanright', 'justic'],
#  ['berlin'],
#  ['returnmyvinyl'],
#  ['chrismukkah'],
#  ['keyboard'],
#  ['bigot', 'misogynist', 'keepyoureyesontheprize'],
#  ['black', 'africanamerican', 'repar'],
#  ['potu', 'trump', 'israel', 'happynewyear'],
#  ['decolon'],
#  ['america'],
#  ['treasonoustrump', 'whiteisi', 'terrorism'],
#  ['ellen', 'kimburrel'],
#  ['newyear', 'prez', 'destruction', 'commercials', 'poopin'],
#  ['shuckin', 'democraticpay'],
#  ['hitler', 'traitor', 'trump'],
#  ['liber'],
#  ['birdsofafeath', 'resist'],
#  ['versace'],
#  ['rich', 'white', 'snob', 'tcot', 'tpc'],
#  ['joke', '2016'],
#  [],
#  [],
#  ['feminismiscanc', 'feminismisterror', 'feminismmuktbharat', 'malevot'],
#  ['tyler', 'perri', 'claim', 'revers', 'criticsâ'],
#  [],
#  ['hypocrit', 'liar', 'inhumaneâ'],
#  ['psa'],
#  [],
#  ['sikh', 'templ', 'calgary', 'wso'],
#  ['allahsoil', 'emirati', '2016in4word'],
#  [],
#  ['mentalhealth', 'firstnations', 'thirdworldcanada'],
#  ['democraticpay', 'blm', 'chicago', 'detroit', 'innâ'],
#  [],
#  ['new', 'phillysuppophilli'],
#  [],
#  ['allahsoil'],
#  [],
#  ['illeg', 'criminals', 'commonsense'],
#  ['deviant', 'barackobama'],
#  [],
#  ['feminist', 'reproductiveright', 'bihcontrol'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['hillaryclinton', 'homophob', 'misogynist'],
#  [],
#  [],
#  ['newyearseve', 'resolut', 'domesticviol', 'love'],
#  ['japan', 'fascism', 'guardian', 'nytim', 'bbc', 'afp', 'rsf'],
#  ['altright', 'maga'],
#  [],
#  ['fear'],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['yehtut', 'rohingya', 'dvbmultimediagroup', 'yehtut'],
#  [],
#  ['gop'],
#  [],
#  [],
#  ['hrc', 'popularvot', 'ca', 'trump'],
#  [],
#  [],
#  [],
#  ['2017in3wordsâ'],
#  ['electoralcolleg', 'trump', 'notmypresid', 'newswith'],
#  ['genocid'],
#  ['lgbtq'],
#  [],
#  ['arab'],
#  ['god', 'cnn', 'foxnew', 'christian', 'conserv', 'christ'],
#  ['censorship', 'freethenippl'],
#  ['bulli'],
#  ['allahsoil'],
#  [],
#  ['grandmoth', 'grandson', 'exist', 'alreadi'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  [],
#  ['blackwomen', 'asianmen', 'datingapp'],
#  ['antirac', 'seashepherd'],
#  ['deplorabal', 'whitesheet', 'inbr'],
#  ['canuck', 'oiler'],
#  ['american', 'bigotri', 'hatr'],
#  ['homophobic', 'warmonger', 'worlddang'],
#  ['trumpsamerica', 'hate'],
#  ['america', 'controversi', 'equal', 'kaepernick', 'nationalanthem'],
#  [],
#  ['laurenduca'],
#  ['hispan', 'black', 'asian', 'cnnâ'],
#  ['hispan', 'retweet', 'boricua', 'miamiâ'],
#  ['hatred', 'xenophobia', 'islamophobia', 'antisemitism', 'war', '2017'],
#  [],
#  ['antirac', 'seashepherd'],
#  ['polit', 'relationship', 'newâ'],
#  ['santa', 'obama', 'soro'],
#  ['allahsoil', 'teambt', 'teamsuperjuniorâ'],
#  [],
#  ['blackonblack',
#   'ris2016',
#   'antiblack',
#   'dogwhistl',
#   'blacklivesmatt',
#   'hamzayusuf'],
#  ['zionazi', 'antisemt'],
#  [],
#  [],
#  ['womenwednesdayâ'],
#  ['dystopian', 'radicalis', 'reveng', 'preorder', '99c'],
#  ['fascism', 'nazi', 'altright', 'richardspenc', 'trumpism', 'dâ'],
#  [],
#  ['trump', 'michelleobama', 'womensmarch', 'women', 'predatorâ'],
#  [],
#  ['sameshitnewyear',
#   'corrupt',
#   'trump',
#   'terrorattack',
#   'fundament',
#   'violenc',
#   'isi',
#   'crisi',
#   'hatr',
#   'murder',
#   'terror'],
#  [],
#  ['bigot'],
#  [],
#  [],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['america'],
#  [],
#  [],
#  [],
#  ['american'],
#  ['altright', 'whitesupremaci'],
#  ['new', 'phillysuppophilli'],
#  ['democrat'],
#  ['europ',
#   'nyt',
#   'libcrib',
#   'uniteblu',
#   'fascism',
#   'trump',
#   'fear',
#   'ignor',
#   'hate'],
#  ['misogyni'],
#  ['aloha', 'fascism', 'warsforoil'],
#  ['antirac', 'seashepherd'],
#  ['theresamay', 'brexit', 'remain'],
#  ['nycâ',
#   'assault',
#   'womenonli',
#   'forher',
#   '2017',
#   'newyear',
#   'resolut',
#   'womenissuesâ'],
#  ['texa', 'justicereform'],
#  ['maddow'],
#  [],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['chepstow', 'gwent', 'wale', 'cymru'],
#  ['familycircu', 'chriâ'],
#  [],
#  ['christian', 'retweetâ'],
#  ['trump'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['childfreeâ'],
#  ['economicapahied', 'hatespeech'],
#  ['asshol', 'rapist', 'pedophil', 'evil', 'satanist'],
#  [],
#  ['stop'],
#  ['joke', '2016'],
#  [],
#  ['feminismiscanc', 'feminismisterror', 'feminismmuktbharat', 'malevot'],
#  [],
#  ['corruptgop'],
#  ['nyc', 'newyork', 'women', 'men', 'bigot'],
#  ['carlpalladino', 'michelleobama'],
#  ['allahsoil'],
#  [],
#  ['politicalmillenni', 'letstalkabout', 'climatechang', 'educationâ'],
#  [],
#  ['notmypresidnet'],
#  ['american', 'bigotri', 'hatr'],
#  ['america', 'controversi', 'equal', 'kaepernick', 'nationalaâ'],
#  ['isra', 'jewish', 'judea', 'samaria'],
#  [],
#  ['gop', 'deplor', 'notfunni'],
#  [],
#  ['swamp', '20day', 'dem', 'taxpay', 'islamicterrorist'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['alexpasc', 'friend', 'music'],
#  ['falsenarr', 'falseequaval'],
#  ['podcast', 'gun', 'igmilitia', 'pewpewlifeâ'],
#  ['bigotry'],
#  ['antirac', 'seashepherd'],
#  ['obama', 'communism', 'islam', 'race', 'nazi'],
#  ['muslim'],
#  ['scienc', 'medicine'],
#  ['love', 'notmypresid', 'resist', '2017'],
#  ['chang', 'antirac'],
#  ['neverump', 'pussygrabberinchief', 'idiocraci'],
#  [],
#  [],
#  [],
#  [],
#  ['gtfoh', 'crackalog'],
#  [],
#  ['allahsoil'],
#  ['men', 'harass', 'verbalassault'],
#  ['polic', 'checkcash', 'atlanta', 'blackmen', 'profil'],
#  [],
#  ['equal', 'divers'],
#  [],
#  [],
#  ['buffalo', 'resign', 'obama', 'carlpaladino', 'newyork'],
#  ['malvern', 'arkansa'],
#  ['nigelfarage', 'immigr'],
#  [],
#  ['sulfur'],
#  ['trump'],
#  ['sisterinlaw', 'frustrated', 'idiots'],
#  ['mexican', 'lmao'],
#  ['mcconnel', 'obama'],
#  ['jew', 'libtard'],
#  [],
#  [],
#  ['truth', 'polic', 'maga', 'audiblechannel'],
#  [],
#  ['sâ'],
#  [],
#  ['trump', 'whitesupremaci', 'fakenew'],
#  ['america'],
#  ['colâ'],
#  [],
#  ['blm'],
#  ['eugen'],
#  ['southafrica', 'leadership', 'transform', 'inequ'],
#  ['hispan', 'retweet', 'boricuaâ'],
#  ['theresist', 'resist', 'resist', 'maga', 'altright', 'raâ'],
#  ['sikh', 'templ', 'calgary', 'wso'],
#  ['treason', 'aidingenemi', 'fraud', 'coverup', 'benghazi', 'extoion17'],
#  [],
#  ['israel'],
#  [],
#  ['notmypr', 'wtf2016', 'neverump', 'unpresid', 'bigot'],
#  ['allahsoil', 'teambtsâ'],
#  ['carl',
#   'paladino',
#   'michel',
#   'obama',
#   'live',
#   'gorilla',
#   'resign',
#   'resign',
#   'stop'],
#  [],
#  ['blm'],
#  ['wiunion'],
#  ['peopl', 'trump', 'republican'],
#  ['racialequ'],
#  [],
#  ['hrc', 'pig'],
#  [],
#  ['trump',
#   'adulteri',
#   'incest',
#   'pedophilia',
#   'bigotri',
#   'hate',
#   'deceit',
#   'maga',
#   'notmypresid'],
#  [],
#  ['crybulli', 'snowflak', 'diversity'],
#  ['humanright'],
#  ['ban', 'say', 'cloth'],
#  ['allahsoil'],
#  ['whitenationalist'],
#  ['notmypresid', 'fucktrump', 'lostpopularvot', 'americadoesntwanty', 'bigot'],
#  [],
#  [],
#  ['theresist', 'resist', 'resist', 'maga', 'altright', 'dt', 'trump'],
#  ['spain'],
#  ['liberals'],
#  [],
#  [],
#  ['misogynist'],
#  [],
#  ['lgbti', 'poc', 'lgbti'],
#  ['putinschoic', 'stoprac', 'boycott'],
#  [],
#  [],
#  ['xenophobia', 'rainbow', 'divers'],
#  [],
#  ['trump', 'obama', 'christmasev'],
#  ['trc', 'indignen'],
#  ['nazi'],
#  ['american', 'bigotri', 'hatr'],
#  ['altright'],
#  [],
#  ['feminist'],
#  [],
#  ['muslim'],
#  [],
#  [],
#  ['femin', 'equal', 'everyon', 'men', 'women'],
#  [],
#  ['thegreenpalmcottag', 'plettenburgbay', 'westerncap'],
#  [],
#  [],
#  ['truth', 'malevot'],
#  ['conserv', 'punk'],
#  [],
#  [],
#  [],
#  [],
#  ['hypocriteâ'],
#  [],
#  [],
#  ['bluelivesmatt'],
#  [],
#  [],
#  ['allahsoil'],
#  ['manipur', 'ndtv', 'timenow', 'samachar', 'zeenew', 'dordarshan', 'genocid'],
#  ['whitepeopl', 'hawaii', 'jlaw', 'disrespect'],
#  ['fakenew', 'fakenewsmedia'],
#  ['returningcitizen'],
#  ['race', 'ethnocentr', 'altright', 'pegida'],
#  ['revolut', 'race', 'intersection', 'languag', 'polit', 'educationâ'],
#  ['corporateb', 'boycottjcpenney'],
#  ['corrupt', 'xenophobia', 'islamophobia', 'homophobia', 'resist'],
#  ['trump'],
#  [],
#  [],
#  ['leftist', 'christian', 'christianity'],
#  ['adamitv'],
#  ['prejudic', 'parent'],
#  ['russia', 'trump', 'tiesto', 'whiteamerica', 'gop', 'communism'],
#  [],
#  ['spiritu'],
#  [],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['allahsoil', 'emirati', '2016in4wordâ'],
#  ['twitteâ'],
#  ['allahsoil', '2016in4word', 'islamâ'],
#  ['notmypresid'],
#  ['fibromyalgia', 'survivor', 'childrape'],
#  ['ass',
#   'hole',
#   'head',
#   'big',
#   'brain',
#   'hea',
#   'love',
#   'truth',
#   'kind',
#   'peac',
#   'compassâ'],
#  [],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  [],
#  ['talkradio'],
#  ['treason', 'trump', 'makeamericagreatagain'],
#  [],
#  [],
#  ['philandocastil'],
#  ['trump', 'economi', 'hype', 'fool', 'idiot'],
#  ['polit', 'media', 'blm', 'brexit', 'trump', 'leadership'],
#  [],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  [],
#  ['whiteslav', 'whiteslaveri', 'venezuela'],
#  ['hispan', 'retweet', 'boricuaâ'],
#  [],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['new', 'phillysuppophilli'],
#  [],
#  [],
#  [],
#  ['antirac', 'seashepherd'],
#  ['rupemurdoch', 'master'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  [],
#  ['depoat'],
#  ['putinschoic', 'putinspuppet', 'retweetâ'],
#  ['stone', 'kill', 'quebec', 'crimin'],
#  ['podcast'],
#  ['nazi', 'swastika', 'ebay', 'trump', 'donaldtrump', 'republic', 'whitepow'],
#  ['pig', 'liar'],
#  [],
#  ['dzang', 'capetown'],
#  ['movi', 'indian', 'challeng', 'rewrit'],
#  ['trumpsamerica', 'feel', 'empowerd', 'fowoh'],
#  ['caturday'],
#  [],
#  ['thank',
#   'dead',
#   'white',
#   'dude',
#   'europe',
#   'nigga',
#   'list',
#   'rapechucktoddâ'],
#  [],
#  [],
#  [],
#  ['iqg', 'â'],
#  [],
#  ['peopl', 'trump', 'republican'],
#  ['allahsoil', 'teambt', 'teamsuperjunior'],
#  ['bluelivesmatt', 'woke', 'manspread', 'ifyourenotwhiteyourenotracist'],
#  ['seashepherd', 'antirac'],
#  ['bigot'],
#  ['doublestanâ'],
#  ['kentucki', 'jcpenni', 'mexican', 'bitchesbelik'],
#  [],
#  ['cleveland', 'ohio', 'white'],
#  ['brexit', 'littleengland'],
#  ['mustread', 'educ', 'stereotyp'],
#  ['bigot', 'trumpproofamerica'],
#  ['sikh', 'templ', 'calgary', 'wso'],
#  [],
#  [],
#  [],
#  ['uspoli', 'potter', 'greed', 'li', 'misogyny', 'fail'],
#  ['bigot'],
#  ['trump', 'uselections2016', 'leadership', 'polit', 'brexit', 'blm'],
#  [],
#  ['climatechang', 'fascism', 'antiegalitarianism', 'narcissism', 'trump'],
#  [],
#  ['miami', 'policebrut', 'newswith'],
#  ['trump'],
#  ['trump'],
#  ['sandnigg'],
#  ['uskkk', 'msm', 'media', 'crazybengiefbps'],
#  ['new', 'phillysuppophilli'],
#  ['buzzfeed', 'manhat'],
#  [],
#  ['shot', 'disparo', 'trompa', 'trumpa', 'migitorio', 'entretei'],
#  ['hatecrim', 'sikh', 'calgari'],
#  ['patriotwatch',
#   'auspol',
#   'rwnj',
#   'upf',
#   'cult',
#   'cultism',
#   'project',
#   'springst',
#   'straya'],
#  ['misogyni', 'left'],
#  [],
#  ['hispan', 'retweet', 'boricuaâ'],
#  ['arrog', 'abus', 'discrimin', 'dutch', 'drs'],
#  [],
#  ['nigger', 'pattismith'],
#  ['in2017iwantto', 'whiteprivilege', 'privilege', 'whiteâ'],
#  ['tcot', 'femin', 'sjw', 'sjwlogic'],
#  ['2017', 'joy', 'love'],
#  ['deaf',
#   'rethinkdiscipline',
#   'ableism',
#   'audism',
#   'stpp',
#   'massincarcer',
#   'deafinprison',
#   'decriminalizâ'],
#  [],
#  ['help'],
#  [],
#  ['resign'],
#  [],
#  [],
#  [],
#  ['liber', 'trump', 'racebait'],
#  ['jacobmarley', 'potter', 'misogynist', 'narrow', 'epicâ'],
#  ['alllivesmatt', 'unbornlivesmatt'],
#  [],
#  ['newyearsev', 'islamophobia', 'femin', 'culturalenrich'],
#  ['race', 'trump'],
#  ['childish', 'paisanhack'],
#  ['neglig', 'hatr', 'injustic', 'climatecrim', 'ecocid', 'trump', '2017'],
#  ['crapsac'],
#  [],
#  ['jcpenni', 'rant'],
#  [],
#  ['bigot', 'trumpworld'],
#  [],
#  ['truth', 'realiti'],
#  [],
#  [],
#  [],
#  ['cologne'],
#  ['cambersand', 'lifeguards', 'wow'],
#  ['marxist', 'propoganda'],
#  ['allahsoil', 'teambtsâ'],
#  ['mustread', 'educ', 'stereotyp'],
#  ['bustymilf'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  [],
#  [],
#  ['michelleobama', 'oprah'],
#  [],
#  [],
#  [],
#  ['palestin', 'standwithisrael'],
#  ['mizzou'],
#  ['allahsoil'],
#  [],
#  [],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['rohingya', 'myanmar'],
#  ['rapist', 'trumpunivers'],
#  [],
#  [],
#  ['dickhol', 'douchebag', 'asshol', 'yousuck', 'mysoginist', 'bigot', 'fear'],
#  ['allahsoil', 'emâ'],
#  [],
#  ['pamgelleheracist', 'mmiw', 'mmiwg'],
#  ['subhuman'],
#  [],
#  ['outrag'],
#  ['blacklivesmatt', 'aryanbrotherhood', 'kkk', 'whiterac', 'alexjon'],
#  ['blackpeopl', 'whiteperson'],
#  ['antisemit', 'misogyni'],
#  ['crookedtrump', 'traitor', 'notamericaschoic', 'bigot'],
#  ['altright', 'homophob', 'theistic', 'troll', 'fightlikeagirlâ'],
#  [],
#  ['woodrowwilson', 'histori', '13th'],
#  ['allahsoil', 'teambtsâ'],
#  ['cover', 'reveal', 'radicalis', 'reveng'],
#  [],
#  ['lifelesson', 'bloggersblast', 'respect'],
#  [],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  ['amandanun'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  [],
#  ['preorder', '99c', 'dystopian'],
#  ['justic', 'humanright'],
#  ['liar', 'nazi', 'brownshi'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['lgbtfamily'],
#  ['usa', 'islam'],
#  ['ladi'],
#  [],
#  ['jew', 'libtard'],
#  ['munmid'],
#  [],
#  [],
#  ['asian'],
#  [],
#  ['allahsoil', 'teambt', 'teamsuperjuniorâ'],
#  ['objectif'],
#  [],
#  ['sexualharass', 'laborviol'],
#  ['libtard', 'regressive', 'insult', 'slur', 'refuted'],
#  ['race'],
#  [],
#  ['black', 'retweet', 'tampa', 'miami', 'newyorkâ'],
#  [],
#  ['gop', 'liar', 'cheater'],
#  ['carlpaladino', 'trump', 'offici', 'underfir', 'obama', 'remark'],
#  [],
#  [],
#  ['feminismiscanc', 'feminismisterror', 'feminismmuktbharat', 'malevot'],
#  ['equal'],
#  ['sikh', 'templ', 'calgary', 'wso'],
#  ['sarcast'],
#  ['bbc', 'euref', 'brexit', 'media'],
#  ['gay', 'jeremyjoseph', 'lgbt'],
#  [],
#  [],
#  ['trumpisâ'],
#  [],
#  ['resign', 'bigot', 'sandyhook'],
#  ['lazioâ'],
#  ['allahsoil', '2016in4wordsâ'],
#  ['smaimmigr', 'zeroattack', 'istanbul', 'religionofpeac', 'reliabl'],
#  ['economicsanct',
#   'russia',
#   'cuba',
#   'china',
#   'whiteprivileg',
#   'whitesupremaci',
#   '2017',
#   'roughwat'],
#  [],
#  [],
#  ['supermistict', 'burninhel'],
#  ['bullying', 'disabl'],
#  [],
#  ['antisemit', 'hocoschool', 'columbiamd', 'hocomd'],
#  [],
#  [],
#  ['leftist', 'snowflak', 'happyholidaysâ'],
#  ['tyrant', 'bigot', 'elitist', 'crook'],
#  ['donaldtrump', 'carlpaladino', 'obama'],
#  ['allahsoil', 'emiratisâ'],
#  ['hillaryclinton', 'obama', 'soro', 'caoon'],
#  ['gover',
#   'left',
#   'womensrighttochoos',
#   'drink',
#   'femin',
#   'hillari',
#   'trump',
#   'discrimin',
#   'obama'],
#  ['misandry', 'misogyni', 'power'],
#  [],
#  ['dumb', 'pelosi'],
#  ['sikh', 'templ', 'calgary', 'wso'],
#  ['kindled', 'bookpublish', 'publish', 'kindl', 'kindled'],
#  ['christian', 'retweetâ'],
#  [],
#  ['hillari', 'trump'],
#  ['microsoft', 'twitterbot', 'tech'],
#  ['africa'],
#  [],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  [],
#  ['po'],
#  ['trump', 'theresist', 'resist', 'hate'],
#  ['socialmooc', 'feliz2017'],
#  ['amwrit'],
#  ['li', 'misogynistâ'],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  ['allahsoil', 'racisâ'],
#  [],
#  [],
#  ['cologne'],
#  ['tcot', 'tlot', 'altright', 'blacklivesmatt'],
#  ['patriotwatch',
#   'auspol',
#   'rwnj',
#   'upf',
#   'cult',
#   'cultism',
#   'project',
#   'springstâ'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['hispan', 'retweet', 'boricua', 'miamiâ'],
#  ['microaggress', 'race', 'whiteprivileg', 'antiblack'],
#  ['human', 'cruel', 'bitter', 'sociopath', 'fugli', 'lunatic'],
#  [],
#  ['presidentpussygrabb', 'notmypresid', 'tinyhand', 'putinpuppet'],
#  ['allahsoil', 'emiratisâ'],
#  ['allahsoil', 'emiratiâ'],
#  ['men', 'harass', 'verbalassault'],
#  ['unless', 'garbag', 'man', 'hillbilli'],
#  ['sikh', 'templ', 'calgary', 'wso'],
#  ['brexit', 'hatecrim', 'nation'],
#  ['american'],
#  ['genocide'],
#  ['treasonoustrump', 'fascist'],
#  [],
#  ['ukrain', 'volodymyrviatrovych', 'histori', 'whitewash', 'jew', 'nazi'],
#  ['ableismâ'],
#  [],
#  ['newyork', 'harass', 'manhattan'],
#  ['love', 'peac', 'relatives'],
#  ['maga', 'maga3x', 'moron', 'hillarylost'],
#  ['denzelwashington', 'morganfreeman', 'willsmith'],
#  [],
#  [],
#  ['bestof2016', 'marriag'],
#  [],
#  ['god'],
#  ['seashepherd', 'antirac'],
#  [],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  [],
#  ['allahsoil'],
#  ['mtv', 'whitepeople', 'ccot'],
#  [],
#  ['confederate', 'audiblechannel', 'histori', 'slaveri', 'southern', 'truth'],
#  ['stloui', 'stl'],
#  ['allahsoil'],
#  [],
#  ['allahsoil', 'emiratisâ'],
#  [],
#  [],
#  [],
#  ['allahsoil'],
#  ['lifelesson', 'blogpost', 'whitepeopl', 'respectâ'],
#  [],
#  ['potu', 'israel', 'obamacar', 'isi', 'energi', 'russia'],
#  [],
#  ['twitter'],
#  ['radic', 'indoctrin'],
#  [],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  [],
#  ['allahsoil', 'racâ'],
#  ['allahsoil', 'teambtsâ'],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  ['maga', 'trump', 'quot', 'quot', 'potu', 'new', 'mediaâ'],
#  ['feminismiscanc', 'feminismisterror', 'feminismmuktbharat', 'malevot'],
#  ['whitepeopl', 'kanyewest', 'racewarchess'],
#  ['muslimbrotherhood'],
#  ['podcast'],
#  ['notmypresid', 'misogynist', 'traitor', 'theresist', 'putinsbitch'],
#  ['good', 'bolt'],
#  ['fuckdonaldtrump', '13thdocumentari', '2017', 'presid'],
#  ['bigot', 'race', 'slaveown', 'fire'],
#  [],
#  ['buffalo', 'newyork', 'trump', 'paladino', 'obamas', 'usa'],
#  [],
#  [],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  ['ufc', 'amandanun', 'rondarousey'],
#  ['allahsoil', 'teambt', 'teamsuperjunior'],
#  ['sad', 'sorelos', 'triggerwarn'],
#  ['stoprac'],
#  [],
#  ['fathersday', 'sistersofcolour', 'â'],
#  [],
#  ['terrorist', 'asshol'],
#  ['antirac', 'seashepherd'],
#  ['2016', 'celebritydeath', 'trump', 'misogyni', 'hate'],
#  [],
#  ['white', 'woman', 'rant', 'hispan', 'women'],
#  [],
#  ['trump'],
#  ['black', 'pornisforlos', 'govegan'],
#  ['brexit'],
#  ['fascist', 'notrump', 'nokkk'],
#  ['ass', 'po'],
#  ['starbuck'],
#  ['allahsoil', 'emirati', '2016in4word'],
#  ['bullying', 'disabl'],
#  [],
#  [],
#  [],
#  ['boycott', 'li', 'divis', 'nationalist', 'foxnew'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  [],
#  ['crazi', 'insan'],
#  [],
#  ['polit', 'câ'],
#  ['kwanzaa', 'nia', 'fascismâ'],
#  ['carriefish', 'feminist', 'ageism', 'hollywood', 'pen', 'acting', 'talent'],
#  ['equal'],
#  ['hispan', 'retweet', 'boricua', 'miamiâ'],
#  [],
#  ['nazi', 'hatred', 'bigotri'],
#  ['whiteman'],
#  [],
#  ['allahsoil'],
#  [],
#  ['catalunya'],
#  ['socialmedia'],
#  ['democrat', 'islamicrad', 'islamophoâ'],
#  ['blacklivesmatt'],
#  ['allahsoil'],
#  ['sikh', 'templ', 'calgary', 'wso'],
#  [],
#  ['wypipo', 'slaverâ'],
#  [],
#  ['santaproject', 'trump', 'hate', 'ivanka', 'macysâ'],
#  [],
#  ['jarodtaylor', 'asslick'],
#  ['whiteprivilege', 'â'],
#  ['australia',
#   'israel',
#   'australian',
#   'opkillingbayã',
#   'thecov',
#   'shabbatshalom'],
#  ['trump', 'uselections2016', 'leadership', 'polit', 'brexit', 'blm'],
#  ['abuse',
#   'pedophilia',
#   'stalking',
#   'harassment',
#   'gaslighting',
#   'ableism',
#   'threats',
#   'suicide',
#   'nsfw',
#   'self'],
#  ['notmypresident', 'theresistaâ'],
#  ['trump', 'uselections2016', 'leadership', 'polit', 'brexit', 'blm'],
#  [],
#  ['drsuess',
#   'moonman',
#   'offens',
#   'kkk',
#   'funni',
#   'comedi',
#   'lol',
#   'edgi',
#   'dankmem',
#   'meme'],
#  ['feminismiscanc', 'feminismisterror', 'feminismmuktbharat', 'malevot'],
#  ['obama', 'face'],
#  ['genocid', 'africa'],
#  ['hispan', 'retweet', 'boricuaâ'],
#  ['japan', 'bulli', 'tweet4taiji'],
#  ['trump', 'adulteri', 'misogyni', 'bigotri', 'incest', 'pedophilia', 'raâ'],
#  [],
#  ['maga'],
#  ['feminismiscanc', 'feminismisterror', 'feminismmuktbharat', 'malevot'],
#  ['allahsoil', 'emirati', '2016in4word', 'ù'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  ['thekingsspeech'],
#  ['shitler', 'maga'],
#  [],
#  [],
#  [],
#  [],
#  ['allahsoil', 'emiratâ'],
#  [],
#  ['bigot'],
#  ['trump'],
#  ['whitefish', 'jewish', 'christian', 'montana', 'naâ'],
#  ['whiteprivileg', 'whitefragil', 'canada'],
#  [],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['sikh', 'templ', 'calgary', 'wso'],
#  ['black', 'retweet', 'tampa', 'miami', 'newyorkâ'],
#  ['fatty', 'black'],
#  ['voterid', 'maga', 'rnc', 'dnc', 'vote'],
#  ['fauxnews', 'religion'],
#  ['trump'],
#  [],
#  ['leftistlunatics'],
#  [],
#  [],
#  ['hate', 'ignor'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['kkk', 'trump', 'chang'],
#  ['sâ'],
#  [],
#  ['black'],
#  [],
#  [],
#  [],
#  ['allahsoil', 'teambt', 'cnn'],
#  [],
#  ['everydayhero', 'bulli'],
#  ['done',
#   'delta',
#   'airlin',
#   'rude',
#   'disrespect',
#   'comment',
#   'action',
#   'neverdelta'],
#  [],
#  ['allahsoil', 'emirati', '2016iâ'],
#  ['hamzayusuf', 'ri', 'jetlag'],
#  ['genderstereotypes'],
#  ['netanyahuspeech'],
#  [],
#  [],
#  ['islamaphobia'],
#  ['justjustic'],
#  [],
#  [],
#  ['blacklivesmatterâ'],
#  ['sikh', 'templ', 'calgary', 'wso'],
#  ['unfittobeinpublicoffic', 'ugli', 'reprehens'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['supermariorun', 'firstworldproblem'],
#  ['womensordinationâ'],
#  ['democrate', 'countri'],
#  ['2016in4wordsâ'],
#  ['fascist', 'putinspuppet'],
#  ['qatar', 'discrimin'],
#  [],
#  [],
#  ['lunat', 'kkk', 'breitba', 'altrightâ'],
#  ['misogynist', 'merrychristma'],
#  ['highereduc', 'southafrica'],
#  ['antirac', 'seashepherd'],
#  ['philandocastil', 'newswith'],
#  [],
#  [],
#  [],
#  ['putinschoic', 'stoprac', 'boycott'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['waitingf', 'wildest', 'cutest', 'takuyakimura', 'highfashion', 'brandâ'],
#  ['bookreview', 'horror', 'mattruffâ'],
#  ['route66', 'segreg'],
#  [],
#  ['kkk', 'cabl', 'disney', 'boycott'],
#  ['nyc', 'newyork', 'women', 'men', 'bigot'],
#  ['cameronstaff', 'camstaff', 'officerstaff', 'acab', 'cowardcopsâ'],
#  ['georgia'],
#  [],
#  ['femin', 'equal', 'asia', 'new'],
#  ['hoodiesup', 'blm'],
#  ['michelleobamaâ'],
#  ['trump'],
#  ['marxist', 'propoganda'],
#  ['nazi', 'hatred', 'bigotri'],
#  [],
#  ['despit', 'demagogueri', 'obstruct', 'fearâ'],
#  ['narcissist'],
#  ['paladinoâ'],
#  ['stopsex', 'womensright', 'women', 'christma', 'trumpâ'],
#  ['narcissimâ', 'misogynyâ', 'toler', 'kind', 'peac', 'hate', 'love'],
#  ['hate', 'all'],
#  ['america', 'misogyni', 'scienc', 'blacksagainsttrump', 'trump'],
#  ['trump'],
#  [],
#  ['pig'],
#  [],
#  ['cjreform',
#   'deathpenalty',
#   'juvenilejustice',
#   'bailreform',
#   'prosecutorialmisconduct'],
#  ['trump', 'uselections2016', 'leadership', 'polit', 'brexit', 'blm'],
#  ['black', 'retweet', 'tampa', 'miamiâ'],
#  ['trump', 'uselections2016', 'leadership', 'polit', 'brexit', 'blm'],
#  ['expat', 'immigrants', 'classism', 'imperialsm'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['newyear', 'prez', 'destruction', 'commercials', 'poopin', 'america'],
#  ['loser', 'thefutur', 'nofear', 'inferioritycomplex'],
#  ['fabul', 'smug', 'elitist', 'annihil', 'voter', 'video', 'trump', 'maga'],
#  [],
#  [],
#  [],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['putinschoic', 'putinspuppet', 'retweetâ'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  [],
#  [],
#  ['rwnj', 'weirdo'],
#  ['paladino', 'libcrib', 'hate', 'mental'],
#  ['intrumpsamerica', 'rapist', 'egomaniac'],
#  [],
#  ['selfi', 'love', 'messi', 'cr7', 'religion', 'christian', 'mecca_l'],
#  ['paladino', 'shame', 'public'],
#  [],
#  ['taharrush', 'taharrushgamea', 'rapeuge'],
#  ['blacktwitt', 'tcot', 'tlot', 'altright', 'bcot', 'blacklivesmatt'],
#  ['afghanistan'],
#  [],
#  ['thegreenpalmcottag', 'plettenburgbay', 'westerncap'],
#  [],
#  [],
#  ['white', 'mannequinchalleng', 'ceo'],
#  [],
#  ['ris2016'],
#  ['white', 'obaman'],
#  [],
#  ['tori',
#   'capitalist',
#   'labour',
#   'socialist',
#   'green',
#   'environmentalist',
#   'liber',
#   'coalitionist',
#   'ukip'],
#  ['hillari'],
#  ['kickitout', 'shelvey'],
#  [],
#  [],
#  ['justic', 'humanright'],
#  ['powerhungrytraitors', 'hereticfoundation'],
#  [],
#  [],
#  ['nationdivider'],
#  [],
#  ['ghostbust', 'misogynist', 'whiner'],
#  ['scrub'],
#  [],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  [],
#  ['kkk', 'trump', 'chang'],
#  ['voterid', 'stillwithh', 'liber', 'democrat', 'wakeup'],
#  [],
#  ['unpresid', 'nohat'],
#  ['psa'],
#  [],
#  [],
#  [],
#  ['trc', 'indignen'],
#  ['trump', 'uselections2016', 'leadership', 'polit', 'brexit', 'blm'],
#  [],
#  ['hollywood', 'solidar', 'onelov'],
#  ['allahsoil', 'teambtsâ'],
#  ['paid', 'kkk', 'fabric', 'stori', 'narr', 'cancel'],
#  ['trump'],
#  [],
#  ['unitedn', 'zionism'],
#  ['saturdayblogshareâ'],
#  ['hillbot'],
#  [],
#  [],
#  ['blacklivesmatt', 'plannedparenthood', 'ideology'],
#  [],
#  ['stupid', 'black', 'white'],
#  [],
#  ['feminismiscanc', 'feminismisterror', 'feminismmuktbharat', 'malevot'],
#  ['po', 'maga', 'usa'],
#  ['sikh', 'templ', 'calgary', 'wso'],
#  ['dumptrump', 'notmypresid', 'deplor'],
#  ['theresist', 'notmypresid', 'russiag', 'votersuppress', 'tyranni'],
#  ['boycott'],
#  ['terror', 'war'],
#  [],
#  ['fascist', 'bigot', 'misogynist', 'sexualpred'],
#  ['beforesex'],
#  ['democrat'],
#  ['cantanker'],
#  ['trump', 'administr', 'hillari', 'liar'],
#  ['allahsoil', 'emirati', '2016in4word'],
#  ['emmaston', 'hollywood', 'movi'],
#  ['5wordtrumplethinskin'],
#  ['wypipo', 'slaveri'],
#  ['zionazi'],
#  ['blm', 'teamd'],
#  ['trump', 'adulteri', 'misogyni', 'bigotri', 'incest', 'pedophilia', 'rape'],
#  [],
#  [],
#  ['israel', 'freedom', 'palestin'],
#  ['2016releas', 'ebook', 'book'],
#  [],
#  ['histori'],
#  ['bigotri', 'dick'],
#  ['miami', 'policebrut', 'newswith'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  ['feminismiscanc', 'feminismisterror', 'feminismmuktbharat', 'malevot'],
#  ['misogyny', 'bigotry', 'childlabor'],
#  [],
#  [],
#  ['tcot', 'femin', 'men'],
#  ['allahsoil'],
#  [],
#  ['feminismiscanc', 'feminismisterror', 'feminismmuktbharat', 'malevot'],
#  [],
#  ['trump', 'politicalcorrect', 'obama'],
#  ['spoti', 'murrayhat', 'murray', 'gazza', 'drunk', 'wifebeaterâ'],
#  ['fascist', '2017fail'],
#  ['libtard', 'sjw', 'liber', 'polit'],
#  [],
#  ['whitegenocid', 'bigot'],
#  ['black', 'retweet', 'tampa', 'miami', 'newyorkâ'],
#  [],
#  ['patriarchi', 'feminist', 'femin'],
#  ['gegenrecht',
#   'nostrach',
#   'fpã',
#   'noafd',
#   'nopegida',
#   'popul',
#   'nonazi',
#   'aufstehn'],
#  ['peopl', 'trump', 'republican'],
#  [],
#  ['adl', 'hate', 'jewworldord', 'tyranny'],
#  ['korean', 'anaco'],
#  [],
#  [],
#  [],
#  ...]

# %%
HT_regular
# Out:
# [['run'],
#  ['lyft', 'disapoint', 'getthank'],
#  [],
#  ['model'],
#  ['motiv'],
#  ['allshowandnogo'],
#  [],
#  ['school', 'exam', 'hate', 'imagin', 'actorslif', 'revolutionschool', 'girl'],
#  ['allin', 'cav', 'champion', 'cleveland', 'clevelandcavali'],
#  ['gr8'],
#  ['ireland', 'blog', 'silver', 'gold', 'forex'],
#  ['orlando',
#   'standwithorlando',
#   'pulseshoot',
#   'orlandoshoot',
#   'biggerproblem',
#   'selfish',
#   'heabreak',
#   'valu',
#   'love'],
#  ['80day', 'gettingf'],
#  ['got7', 'junior', 'yugyoem', 'omg'],
#  ['thank', 'posit'],
#  ['friday', 'cooki'],
#  [],
#  ['euro2016'],
#  ['badday', 'coneofsham', 'cat', 'piss', 'funni', 'laugh'],
#  ['wine', 'weekend'],
#  ['tgif', 'gamedev', 'indiedev', 'indiegamedev', 'squad'],
#  ['upsideofflorida', 'shopalyssa', 'love'],
#  ['smile', 'media', 'pressconfer', 'antalya', 'turkey', 'throwback'],
#  ['ica16'],
#  [],
#  ['rip', 'orlando'],
#  [],
#  ['alohafriday', 'time', 'not', 'exist', 'positivevib', 'hawaiian'],
#  [],
#  ['goodnight', 'badmonday'],
#  ['taylorswift1989'],
#  ['travelingram', 'dalat', 'ripinkylif'],
#  ['photoshop',
#   'enoughisenough',
#   'dontphotoshopeveryth',
#   'wheresallthenaturalphoto'],
#  ['cedarpoint'],
#  ['thank', 'posit'],
#  ['bookworm', 'ontothenextnovel'],
#  [],
#  [],
#  [],
#  ['flow', 'grow', 'garden', 'iphonesia', 'bliss', 'bloom', 'basilicabotanica'],
#  ['i_am', 'posit', 'affirm'],
#  ['model'],
#  ['whenev', 'someth', 'wrong'],
#  ['illustr'],
#  [],
#  ['abc2020', 'pulseclub', 'prayfororlando'],
#  ['bihday', 'nose', 'job', 'bihday', 'petunia'],
#  ['albanpilgrimag'],
#  [],
#  ['wedding'],
#  [],
#  ['video', 'father', 'day', 'rayo', 'world', 'hotvideo', 'video'],
#  ['ascot', 'fashion', 'monochrom', 'style', 'instahappyday'],
#  ['selfi', 'yolo', 'xoxo', 'like4lik'],
#  ['work', 'mindset'],
#  ['christinarip', 'voic', 'christinagrimmi'],
#  ['roar', 'preschool', 'student', 'proudâ'],
#  [],
#  [],
#  ['chatiado'],
#  [],
#  [],
#  ['travel', 'yeah', 'thejourneybegin', 'helloâ'],
#  ['luv', 'hottweet', 'venusexchangeâ'],
#  ['awork', 'solut'],
#  ['orlando', 'disneygatorattack'],
#  [],
#  ['proud'],
#  ['udtapunjab', 'amarinder', 'aap'],
#  ['senseaboutmath'],
#  [],
#  ['golfstrengthandcondit', 'strong', 'felixfoisgolf'],
#  ['greathonour', 'careerconvo'],
#  ['innov', 'wateringhol', 'cave', 'mountaintop', 'campfir'],
#  [],
#  ['heal', 'altwaystoh', 'healthi', 'peace'],
#  [],
#  [],
#  ['midweek', 'newmus', 'watchthisspac', 'guitar'],
#  [],
#  [],
#  ['snapchat', 'redhead', 'vermillionr'],
#  ['peopl'],
#  ['goodtim', 'histori'],
#  ['summeim', 'memori'],
#  ['memori'],
#  [],
#  ['model'],
#  [],
#  ['hump', 'hump', 'humpersð'],
#  ['shop', 'cool', 'home', 'fun'],
#  [],
#  [],
#  ['nashvilletour2016', 'nashvilleforev'],
#  ['eur', 'blog', 'silver', 'gold', 'forex'],
#  [],
#  ['thank', 'posit'],
#  ['christinagrimmi', 'prayfororlando'],
#  ['eyelid'],
#  ['vigilfororlando', 'harp', 'clonakilti', 'rip'],
#  ['ihavenofriend', 'someonecomewithm'],
#  ['weekend', 'relax', 'icon', 'woman', 'sundaymorn', 'sunday', 'marilynmonro'],
#  [],
#  ['marvel', 'song', 'musica', 'weed', 'ripchristina', 'adel', 'danc'],
#  ['under', 'blog', 'silver', 'gold', 'forex'],
#  ['healthi', 'altwaystoheal'],
#  ['model'],
#  ['ofw', 'pinoy', 'followm', 'iger', 'instagood', 'smile', 'love'],
#  ['toradora', 'anim', 'animeedit', 'breakup', 'alon', 'lone'],
#  [],
#  ['cotd'],
#  [],
#  ['footbal', 'snapchat'],
#  ['fringes', 'qcbags', 'summ'],
#  ['nochebuena', 'lasvega', 'usa'],
#  ['instaboy',
#   'instaman',
#   'sefie',
#   'septum',
#   'friend',
#   'smiles',
#   'blackandwhit'],
#  ['haiku', '3line', 'micropoetri'],
#  ['jewelrymak', 'button'],
#  ['weston'],
#  ['eo', 'fun', 'cawaii', 'love', 'strawberri', 'tomato'],
#  ['boy', 'guy'],
#  ['social', 'analyt', 'photooftheday', 'iger', 'like'],
#  ['doj', 'fbi', 'emailg', 'hillary2016', 'shame', 'disgrac', 'ridicul'],
#  ['stupid', 'negligence', 'sachintendulkar'],
#  ['ã', '21thbihday', 'bestfriend', 'loveð'],
#  ['enjoy', 'pooh4u'],
#  ['chrisevan', 'bihdayâ'],
#  ['florida'],
#  ['newalbum', 'indi', 'guitar', 'echobelli'],
#  ['tgif', 'webmaret', 'seo', 'commun', 'manag', 'weekend'],
#  ['nzd', 'blog', 'silver', 'gold', 'forex'],
#  ['bihdayweeksuck', 'bithday27', 'tâ'],
#  [],
#  ['disneysmagickingdom', 'disney', 'magickingdom', 'disneyland', 'orlandoâ'],
#  [],
#  [],
#  [],
#  ['healthi'],
#  ['love', 'commit', 'trust', 'faith'],
#  ['newarkfestiv'],
#  ['mochithepug', 'puglif'],
#  [],
#  ['justalil', 'butstillontim'],
#  ['goodmorn', 'friday', 'girl', 'love', 'florida'],
#  ['aap', 'punjabi', 'drugaddicts'],
#  ['tracerequest', 'touch'],
#  ['guy', 'mato', 'chapon'],
#  ['friend'],
#  ['model'],
#  ['bloke'],
#  [],
#  ['vfest', 'summer'],
#  ['bihday', 'shane', 'watson', 'australia', 'cricker'],
#  ['whoknows'],
#  ['radio1', 'coldplay'],
#  [],
#  [],
#  ['gloucesterrugbi'],
#  [],
#  ['sad',
#   'togeth',
#   'alon',
#   'down',
#   'fine',
#   'dandi',
#   'lone',
#   'exuber',
#   'depress',
#   'halfful',
#   'halfempti'],
#  ['mikeashley', 'sposdirectsham', 'workersright', 'euref', 'remain'],
#  ['bird', 'stella', 'bad', 'princess'],
#  [],
#  ['realli'],
#  [],
#  ['orlando', 'heabreak'],
#  ['runbeck', 'happi', 'quot', 'inspir'],
#  ['acne', 'altwaystoh', 'healthi', 'healing'],
#  ['beat', 'makingbeat', 'thursday', 'work', 'istandard', 'akaiproâ'],
#  ['wed', 'weddingpay', 'love', 'forev', 'weddingdressâ'],
#  ['cpd', 'onemoreday'],
#  ['twitch', 'stream'],
#  ['verbal', 'abus', 'love', 'adult', 'teen'],
#  [],
#  ['thank', 'posit'],
#  ['dejeun', 'lunch', 'happi', 'love', 'amoureuxâ'],
#  ['lawofattract', 'quiz', 'love', 'happi', 'motiv', 'success', 'joy', 'lifeâ'],
#  ['pole', 'bgp', 'rozthediva', 'blackgirlspol', 'bodyandpol', 'live', 'love'],
#  ['argentina2015'],
#  [],
#  ['nohcarolina'],
#  ['build'],
#  ['ksleg'],
#  ['orlando'],
#  ['aly_alshahawi',
#   'cute',
#   'summer',
#   'photographerdubai',
#   'sun',
#   'hair',
#   'mydubaiâ'],
#  [],
#  [],
#  ['i_am', 'posit', 'affirm'],
#  ['thank', 'posit'],
#  [],
#  ['wimbledon2016'],
#  ['success',
#   'model',
#   'entrepreneur',
#   'speaker',
#   'fresh',
#   'confid',
#   'fashionâ'],
#  ['gala', 'day', 'kid', 'bipolar', 'frikiegirl2016'],
#  [],
#  ['amaz', 'dad', 'enjoy'],
#  ['magnettherapi', 'altwaystoh', 'heal', 'healthi'],
#  [],
#  ['smile', 'egsmil', 'torio'],
#  [],
#  [],
#  ['bu', 'alamindah', 'white', 'music', 'carrieunderwood'],
#  ['model'],
#  [],
#  ['propey', 'ocean', 'summer', 'life', 'famili'],
#  ['quot',
#   'quot',
#   'love',
#   'pakistan',
#   'allin216',
#   'girl',
#   'boy',
#   'fashion',
#   'feel'],
#  ['thank', 'posit'],
#  ['countdown', 'nolefam', '22092016'],
#  [],
#  [],
#  ['wakow', 'buzz', 'moment', 'ride', 'love', 'crush', 'date', 'hookup', 'app'],
#  [],
#  ['risay18', 'risaypl'],
#  ['thursday'],
#  ['i_am', 'posit', 'affirm'],
#  [],
#  ['thank', 'bless', 'jeffreycwilliam'],
#  ['buttru'],
#  ['cute', 'smile', 'babygirl', 'beauti', 'niec', 'bless'],
#  ['t', 'oneteamlincoln'],
#  ['rockthepark', 'timetogetmyjesuson'],
#  [],
#  ['happi'],
#  ['sanjapan', 'animeconvent'],
#  ['tech', 'announc', 'moto_', 'question'],
#  ['mondaymotiv', 'livelifetothefullest', 'healthi', 'everydaycount'],
#  ['classmat', 'friend'],
#  ['brentwood', 'homesta'],
#  ['kitten', 'cat', 'blackkittenâ'],
#  [],
#  [],
#  [],
#  ['pharrellwilliam'],
#  ['workâ'],
#  ['gut', 'rosi'],
#  ['fever'],
#  ['mad', 'teeth', 'bite', 'piss', 'dog', 'bite', 'dogbit', 'dogtreat'],
#  ['dreamcatch'],
#  ['englishteach', 'teacher', 'ecuador'],
#  ['strong', 'greatquotesâ'],
#  [],
#  ['itako', 'alone', 'it'],
#  ['letthembelittl', 'childhoodunplug'],
#  ['calm', 'sunni', 'chubbygirl', 'glass', 'finnishgirl', 'finn'],
#  ['yuhuuuuu', 'tmaâ'],
#  ['nationalbestfriendsday', 'true'],
#  [],
#  ['ugh'],
#  ['model'],
#  ['game', 'game', 'girlgam', 'voez'],
#  ['weekend'],
#  [],
#  ['beyou', 'ofbham'],
#  ['fathersday', 'love'],
#  ['æ'],
#  [],
#  ['positivevib', 'fresh'],
#  ['conjuring2', 'readyornot', 'truestori'],
#  [],
#  ['iwearbanana'],
#  ['scare', 'redditchbizhour'],
#  [],
#  ['smile', 'corbinrayp'],
#  ['scare', 'missyou', 'whatwasthat'],
#  ['mondaymorn', 'mondaymotiv', 'monday', 'indraloka'],
#  ['sanasafinaz', 'noexchangepolici'],
#  ['ending'],
#  ['littlebear',
#   'joy',
#   'toddlerfriend',
#   'puresweet',
#   'latergram',
#   'toddlerfun'],
#  [],
#  ['orlando'],
#  [],
#  ['pharrel'],
#  [],
#  [],
#  ['real', 'tru'],
#  ['slut',
#   'snapshot',
#   'hot',
#   'nasti',
#   'naughti',
#   'sexi',
#   'horni',
#   'shi',
#   'porn',
#   'nude',
#   'kinki',
#   'xxx',
#   'y'],
#  ['thankfulthursday'],
#  ['i_am', 'posit', 'affirm'],
#  ['canadianrav'],
#  ['michaelkor', 'luckygirl', 'bihday', 'liverpool'],
#  [],
#  ['freakshak', 'freak', 'yum', 'dalston'],
#  [],
#  ['thank', 'posit'],
#  [],
#  ['vegan',
#   'organ',
#   'fresh',
#   'fruit',
#   'organ',
#   'healthi',
#   'healthyliv',
#   'life'],
#  ['sad'],
#  [],
#  ['blackpool'],
#  ['fathersday'],
#  [],
#  ['newblood16'],
#  ['funer'],
#  [],
#  [],
#  ['usa'],
#  ['stephcurry', 'nbafin'],
#  ['grate', 'affirm'],
#  ['missyou', 'mybrotherskeep'],
#  [],
#  ['friday', 'weird'],
#  [],
#  ['direction',
#   'niall',
#   'nialhoranfact',
#   'niallerwin',
#   'hot',
#   'justindrewbieb',
#   'justindb',
#   'believetou'],
#  ['father', 'sanya', 'whererefreshingbegin'],
#  ['lifeaftersurgeri',
#   'dog',
#   'dogslif',
#   'labrador',
#   'labradorretriev',
#   'lifeofsam'],
#  ['glastofest'],
#  [],
#  [],
#  ['mep', 'webseri'],
#  ['model'],
#  ['juneteenth',
#   'independenceday',
#   'food4thought',
#   'rich',
#   'ancestr',
#   'heritag'],
#  ['river'],
#  ['pathet', 'ripgop'],
#  [],
#  [],
#  ['smile', 'instalik', 'instamood', 'instap'],
#  ['graffiti',
#   'dublin',
#   'ireland',
#   'music',
#   'vimeo',
#   'movi',
#   'video',
#   'europ',
#   'peopl',
#   'flow',
#   'fun',
#   'rafalwojcicki'],
#  ['oitnbseason4'],
#  ['iamposs', 'extraordinaryladyspeak', 'staraward'],
#  ['breakfast', 'sun', 'day', 'sunnyday', 'sun', 'blueâ'],
#  ['yellowjacket', 'neshl', 'bhl', 'hockey'],
#  ['tonyaward'],
#  ['fathers', 'day', '2016'],
#  ['countri', 'rock', 'bluegrass', 'beatl', 'love', 'pop', 'romanc'],
#  ['project', 'blog', 'silver', 'gold', 'forex'],
#  ['300dayshappi',
#   'dayseventyseven',
#   'day77',
#   'happi',
#   'love',
#   'lifequot',
#   'lifeâ'],
#  [],
#  ['bihday'],
#  ['thank', 'posit'],
#  [],
#  ['quiet', 'july4th', 'firework'],
#  [],
#  ['paratyphoid'],
#  ['thevoic', 'stoptheh', 'ripchristina'],
#  [],
#  [],
#  ['enjoy', 'music', 'today', 'free', 'app', 'free', 'music'],
#  ['lawofattract', 'resourc', 'healing', 'altwaystoh', 'healthi', 'idwp'],
#  [],
#  ['music', 'therapi', 'healing', 'altwaystoh', 'healthi'],
#  [],
#  ['salud', 'ch', 'smile'],
#  ['nofilt'],
#  ['overwhelm', 'happi'],
#  [],
#  ['buffalo'],
#  [],
#  ['thebachelorett', 'empti', 'nowin'],
#  [],
#  ['good', 'faith', 'vaitacacommafiasdv'],
#  ['love', 'success', 'work', 'businessâ'],
#  ['torrington', 'lunch', 'afterschool', 'instadaili', 'yummi', 'withmom'],
#  [],
#  ['cycl', 'sunset', 'ride', 'bike', 'fit', 'cardio', 'deseâ'],
#  [],
#  ['tagsforlik',
#   'food',
#   'friends',
#   'summer',
#   'swag',
#   'quot',
#   'love',
#   'god',
#   'girl',
#   'weekend',
#   'polaroid',
#   'followm',
#   'teen',
#   'win',
#   'job'],
#  ['payintheusa'],
#  [],
#  ['stellar', 'girl', 'dreami', 'goodmorn'],
#  [],
#  [],
#  ['yay', 'wednesdaywisdom'],
#  ['forev'],
#  ['bee'],
#  ['beauti', 'smooth', 'lifestyl', 'skin', 'instas', 'f4f', 'fashion'],
#  ['lawofattract', 'heal', 'loa', 'healthi', 'well', 'idwp'],
#  ['oil', 'blog', 'silver', 'gold', 'forex'],
#  ['newblood'],
#  ['first',
#   'bihday',
#   'puppi',
#   'elois',
#   'sweetbabin',
#   'dog',
#   'growingup',
#   'cute',
#   'bihdaygirl'],
#  [],
#  ['prayfororlando', 'guncontrol'],
#  ['smile', 'lovethemâ'],
#  [],
#  ['ombr', 'blue'],
#  ['warcraft'],
#  ['family', 'fun'],
#  [],
#  [],
#  ['lover', 'friend', 'astrolog', 'love'],
#  [],
#  ['sdl326am'],
#  ['summev', 'zoo'],
#  ['heal', 'altwaystoh', 'healthi'],
#  ['roar', 'tiger', 'annaswelshzoo', 'bihdaycelebr'],
#  ['laugh', 'xtra'],
#  ['positivevib', 'sunshin', 'sunday'],
#  [],
#  ['masterkeyexperi'],
#  ['face', 'pizza'],
#  ['sisteradventur', 'sister', 'ilovemysisterâ'],
#  [],
#  ['usn', 'navi'],
#  ['euro'],
#  ['happi', 'minion'],
#  ['bethesda', 'e32016'],
#  ['tiggi', 'jax', 'soa', 'throwbackthursday'],
#  ['eurogam', 'pump', 'eurogamer2016'],
#  ['staytun', 'tapfoag'],
#  ['sun',
#   'love',
#   'outdoor',
#   'picnic',
#   'summer',
#   'famili',
#   'daughter',
#   'father',
#   'dess',
#   'icecream'],
#  ['retailtherapi', 'riverisland', 'shoppingqueen', 'alwayscheersyouup'],
#  ['clean', 'laundryday'],
#  ['ebay', 'woohoo', 'sell', 'sell', 'buy', 'shop', 'shop'],
#  ['thank', 'posit'],
#  ['chill'],
#  ['instagood', 'ì', 'å', 'idola', 'idol', 'à¹', 'followm', 'selfi', 'ã'],
#  ['christinagrimmi', 'orlando', 'america'],
#  ['brexit', 'blog', 'silver', 'gold', 'â'],
#  ['eacbpm', 'busi'],
#  ['alohabeachbu', 'hawaii', 'explor'],
#  [],
#  ['great'],
#  [],
#  ['bird', 'download', 'film', 'ita'],
#  ['sunday',
#   'photo',
#   'model',
#   'urbex',
#   'topless',
#   'tit',
#   'mono',
#   'retweet',
#   'sexi',
#   'heel',
#   'ace'],
#  [],
#  ['shegotmarri'],
#  ['model'],
#  [],
#  ['soccer', 'spring', 'season'],
#  [],
#  ['sun', 'fun', 'beachpark'],
#  ['euros2016'],
#  ['anim', 'love', 'stori', 'not', 'end', 'like4likeâ'],
#  ['poet'],
#  ['i_am', 'posit', 'affirm'],
#  ['2pm', 'kpop'],
#  ['essentialoil', 'anxieti', 'healthi', 'peac', 'altwaystoh'],
#  [],
#  ['gettingold', 'becomingbor', 'notborderland', 'goblizzard'],
#  ['fatkidinacandystor'],
#  ['snapshot',
#   'young',
#   'shi',
#   'kinki',
#   'wet',
#   'porn',
#   'hot',
#   'xxx',
#   'horni',
#   's'],
#  ['love', 'girl', 'snapchat', 'flower', 'instasmil', 'instaloveâ'],
#  ['i_am', 'posit', 'affirm'],
#  [],
#  ['acne', 'altwaystoh', 'healthi', 'healing'],
#  ['msgapparelstoday'],
#  ['lovecamp', 'brownwood'],
#  ['grate', 'affirm'],
#  ['forev',
#   'karaok',
#   'friend',
#   'friendship',
#   'love',
#   'nofilt',
#   'instacool',
#   'instagood'],
#  ['318'],
#  ['thealter'],
#  ['blog', 'silver', 'gold', 'forex'],
#  ['fathersday', 'love'],
#  ['motiv'],
#  ['violent', 'world'],
#  ['funni', 'truestori'],
#  ['monday', 'menmodelsâ'],
#  [],
#  [],
#  ['oitnbseason4'],
#  [],
#  ['noooo', 'whyyyy', 'loveyoudesi'],
#  ['jordan', 'paid', 'wear', 'lowtopsâ'],
#  ['i_am', 'posit', 'affirm'],
#  ['salut'],
#  ['nyc', 'newyorkc', 'myview', 'wine', 'fridaynightâ'],
#  [],
#  ['love', 'bless'],
#  [],
#  ['danian', 'love', 'colour', 'rainbow'],
#  ['aiel', 'aielmaharashtra', 'irrit'],
#  ['rocksteddi', 'band', 'enjoy', 'idol', 'omg'],
#  ['cheapshot', 'lowblow', 'shame'],
#  ['parent', 'tantrum', 'toddler', 'calm', 'mind', 'strong'],
#  ['i_am', 'posit', 'affirm'],
#  ['siri', 'maco', 'wwdc2016'],
#  ['diy', 'dresser', 'nicknack', 'newelectricscrewdriv'],
#  [],
#  [],
#  ['choic', 'alway'],
#  ['ë', 'ê', 'ì'],
#  ['app', 'june', 'issu', 'bazaarmagâ'],
#  [],
#  [],
#  [],
#  ['enjoy',
#   'greec',
#   'crete',
#   'sabinedrift',
#   'chillinn',
#   'blondegirl',
#   'bluedressâ'],
#  [],
#  ['gamereadi'],
#  ['summer', 'life', 'no_school', 'tahiti', 'like'],
#  ['stupidthought', 'quot', 'lmao'],
#  ['downasquadmemb', 'treeout'],
#  ['japan', 'blog', 'silver'],
#  ['bbuk'],
#  ['good', 'morn'],
#  ['fridayfeel', 'relax', 'bristol'],
#  [],
#  ['rap', 'hiphop', 'rock', 'funni', 'comedi', 'pop', 'kanyewest'],
#  ['merri', 'christma', 'new', 'year', 'freepik', 'decor'],
#  [],
#  ['test', 'tire', 'annoy', 'whi'],
#  ['anxieti', 'altwaystoh', 'heal', 'peac'],
#  [],
#  [],
#  ['periscope', 'collegebound'],
#  ['nervou', 'curiou', 'bringiton'],
#  ['lifegroup'],
#  [],
#  ['lawofattract', 'resourc', 'healing', 'altwaystoh', 'healthi', 'idwp'],
#  ['surfday', 'fathersday', 'dad', 'novyspos', 'novytowel', 'surfgear'],
#  [],
#  [],
#  [],
#  [],
#  ['showyourjeepday', 'jeepmafia', 'jeeplif', 'jeep'],
#  [],
#  ['ä½'],
#  ['gratitud', 'laurasworld'],
#  [],
#  ['nbafin'],
#  ['uot', 'savecharity', 'tragic', 'rip'],
#  ['space', 'blue', 'fabricsourc', 'finish', 'pillow', 'cushion'],
#  [],
#  [],
#  ['fathersday', 'dad', 'financi', 'future', 'save', 'insur', 'invest'],
#  ['saturday', 'weekend'],
#  ['fathersday'],
#  ['footbal'],
#  ['buxton', 'grumpi'],
#  [],
#  ['troopingthecolour', 'thequeenat90'],
#  ['work', 'fusiona', 'develop', 'chase'],
#  ['hamster', 'rip', 'imissy'],
#  ['love'],
#  ['love', 'boyfriend', 'smile'],
#  ['icrs2016'],
#  ['fun'],
#  ['lichfield'],
#  ['surpris', '2like', 'unexpect'],
#  [],
#  [],
#  [],
#  ['embarrass'],
#  ['internationaldayofyoga2016',
#   'yogalov',
#   'yoga',
#   'relax',
#   'healthi',
#   'positiveâ'],
#  [],
#  [],
#  ['coldplay', 'conc', 'hampden', 'fave', 'coupl', 'cute'],
#  ['heal', 'altwaystoh', 'healthi', 'peace'],
#  ['flagday', 'texa', 'householdnam', 'takingoverâ'],
#  [],
#  ['cat', 'furry', 'persiancat', '4798'],
#  ['tgif', 'kiss', 'kiss', 'friday', 'fridayfun'],
#  ['bless', 'thank'],
#  ['euro2016'],
#  [],
#  ['theriveourberlin', 'theboss'],
#  ['nowplay', 'sick', 'littl', 'world', 'live', 'set'],
#  ['2ndamend'],
#  ['dog'],
#  ['boohiss'],
#  ['whenrealtorscompeteyouwin', 'callm', 'gotheextramileâ'],
#  ['poaventura', 'whatajok'],
#  ['dcvote'],
#  ['eur', 'blog', 'silver', 'gold', 'forex'],
#  ['elections2016', 'america', 'smh', 'usa'],
#  ['anim', 'puppi', 'vine', 'magic', 'subscrib', 'youtub'],
#  [],
#  [],
#  ['dad', 'fathersday', '2016', 'intellicr'],
#  [],
#  ['pwcproud'],
#  ['love', 'instagood', 'tbt', 'cute', 'beauti', 'followm'],
#  ['weekend', 'famili', 'home'],
#  ['tragic', 'puls', 'orlandostaystrong', 'thoughtsandprayersâ'],
#  ['yrkkh', 'uglyspat'],
#  [],
#  ['thekil'],
#  [],
#  ['travel',
#   'tim',
#   'instamood',
#   'moment',
#   'love',
#   'mylif',
#   'russian',
#   'girl',
#   'model',
#   '4likeâ'],
#  ['tuesday',
#   'jacki',
#   'quot',
#   'taketim',
#   'soul',
#   'enjoylif',
#   'smile',
#   'believ',
#   'dream',
#   'havefun'],
#  ['edinburgh', 'scotland', 'homesweethom', 'famili'],
#  [],
#  [],
#  ['thank', 'posit'],
#  ['studiotim'],
#  [],
#  ['cfisdrrr'],
#  ['prettypussi', 'sexybbw', 'realmvp'],
#  ['excitâ'],
#  [],
#  [],
#  [],
#  ['stone', 'gift', 'amaz', 'beauti'],
#  ['lfc', 'ynwa', 'englishpremierleagu'],
#  ['rogergoodell', 'fathersday', 'goodellsucksâ'],
#  ['orb', 'blog', 'silver', 'gold', 'forex'],
#  [],
#  [],
#  ['lovey', 'fathersday', 'sunday', 'father', 'daddi'],
#  [],
#  ['actor', 'seeklearn', 'stafresh'],
#  [],
#  ['bastard'],
#  ['socialmedia'],
#  ['smaphon'],
#  ['lifeisbeauti', 'loveit', 'workhard', 'trainhard', 'bless', 'fitlifeâ'],
#  ['spo', 'dure', 'lui', 'oscar'],
#  ['njoyhit40', '1hitmusicst', 'nice', 'nyc'],
#  ['personaltrain'],
#  [],
#  ['thank', 'posit'],
#  ['melancholi', 'melancholymus'],
#  ['tvk3fathersday'],
#  ['thank', 'posit'],
#  ['thank', 'posit'],
#  [],
#  ['love', 'sinkthepink', 'music', 'instagay', 'celebspot'],
#  ['ccmf2016', 'mychurch', 'frontrow', 'upshow'],
#  ['stupid', 'africa'],
#  ['gold', 'blog', 'silver', 'gold', 'forex'],
#  ['horrif', 'unforgiv'],
#  ['i_am', 'posit', 'affirm'],
#  ['instatravel',
#   'instamo',
#   'igdaili',
#   'instagramhub',
#   'instagood',
#   'instalik'],
#  ['lonely'],
#  ['girliguessimwithh'],
#  ['mobil', 'whitepap'],
#  [],
#  ['work', 'mindset'],
#  ['rochest'],
#  [],
#  ['tattoosleev'],
#  [],
#  ['tell', 'river', 'complain', 'philosophi', 'proverb'],
#  ['thank', 'posit'],
#  [],
#  ['happi', 'lifecoach', 'reinventimposs'],
#  [],
#  ['thank', 'posit'],
#  ['outsid',
#   'thepeel',
#   'work',
#   'homophob',
#   'taxi',
#   'driver',
#   'guy',
#   'kiss',
#   'gay',
#   'melbourn',
#   '13cab'],
#  [],
#  ['smile', 'kind'],
#  ['windows10', 'browser', 'customcasetab', 'noedit'],
#  [],
#  ['whi'],
#  ['totalpolitician', 'outoftouch', 'disgrac'],
#  ['fathersday'],
#  ['truth', 'suicid', 'blackboy'],
#  ['homesweethom',
#   'amaz',
#   'love',
#   'istanbul',
#   'girl',
#   'beauti',
#   'instalik',
#   'meâ'],
#  [],
#  [],
#  ['swing', 'mybabygirl', 'babi', 'littlegirl', 'park', 'love', 'cute'],
#  ['winter', 'bathtim', 'cozi'],
#  ['i_am', 'posit', 'affirm'],
#  [],
#  ['sunflow', 'natur', 'garden', 'photograpi'],
#  [],
#  ['growth', 'hack', 'confer', 'growthwithhubspot'],
#  ['dog', 'sunshin', 'dogsoftwitt'],
#  ['sleepnumb', 'bonustolongrest', 'dnd'],
#  ['satisfi', 'hair', 'workit', 'smile', 'faceâ'],
#  ['sunday', 'weekend', 'selfi', 'longhair', 'girl', 'selfporait', 'loveâ'],
#  ['nature_perfect'],
#  ['model'],
#  ['039'],
#  ['golinuntern'],
#  ['grimm', 'nadalind'],
#  [],
#  ['disrespectful', 'frustrat'],
#  ['friday', 'pub', 'ilovehim', 'instagay', 'beer'],
#  [],
#  [],
#  [],
#  ['fruit', 'dess', 'instamo', 'photooftheday', 'yvr', 'sweet', 'vancitybuzzâ'],
#  [],
#  ['iqbal', 'galib', 'wasi', 'faraz', 'mohsin'],
#  ['armaanamaalontkss'],
#  ['royal', 'cleveland', 'disgrac'],
#  [],
#  ['latina'],
#  ['orlando'],
#  ['triathlet', 'triathlon', 'coach', 'vacat', 'fearless', 'rulâ'],
#  ['reflect'],
#  ['gratitud'],
#  [],
#  ['takalot', 'bengreenfield'],
#  ['saysometh'],
#  [],
#  [],
#  ['slugg'],
#  ['awesom', 'beat', 'cool', 'danc', 'edm', 'hous', 'goodmus', 'madnessâ'],
#  ['jpy', 'blog', 'silver', 'gold', 'forex'],
#  [],
#  ['steakandshak', 'not'],
#  ['grayneedstogo'],
#  ['leadership', 'inspir', 'quot', 'inspir'],
#  ['usd', 'blog', 'silver', 'gold', 'forex'],
#  ['r1rockallday', 'nois'],
#  ['loveherbreakup', 'hotgoss'],
#  ['sunshine', 'sunshine'],
#  ['game', 'gamer', 'xboxon', 'playstat', 'e32016'],
#  ['bringbackgladiators'],
#  ['humpday',
#   'life',
#   'lifestyl',
#   'wednesday',
#   'midweek',
#   'snapchat',
#   'walru',
#   'funnyâ'],
#  [],
#  ['archiveday', 'weekendblogshar', 'happi', 'quot', 'tshi'],
#  ['goodtogreat', 'inspirem', 'love'],
#  ['london', 'puppi', 'thursdaymotiv'],
#  ['draw', 'blackandwhit'],
#  ['romances', 'horror', 'moviegenr', 'ambianc'],
#  ['wildlifefestiv'],
#  ['ewabeach', 'magicalhappydrink'],
#  ['pleasedontchang'],
#  ['holiday', 'croatia', '13daystogo'],
#  [],
#  ['newyork', 'newyorkc', 'travel', 'bigappl'],
#  ['motiv'],
#  ['fashionblog'],
#  ['becauseofhim', 'inlov'],
#  ['smile', 'love', 'iminlov', 'iam', 'nice', 'day'],
#  ['monaco',
#   'resto',
#   'chezedgard',
#   'grandprixf1',
#   'essais',
#   'sun',
#   'lewissuppo',
#   'ð',
#   'amour',
#   'love'],
#  ['toread', 'letsmak'],
#  ['sukhbir', 'badal', 'eastcoast', 'canada'],
#  [],
#  ['shop', 'cool', 'home', 'fun'],
#  [],
#  ['scottieandrussel', 'work', 'love', 'picofthedayâ'],
#  ['rain', 'water', 'tbt', 'weather', 'bribieisland'],
#  [],
#  ['wed', 'love'],
#  ['icymi', 'debelop', 'gun'],
#  ['schoolsuppli'],
#  ['babiescat', 'cat', 'newborn', 'congratul'],
#  ['pretending',
#   'to',
#   'b',
#   'when',
#   'you',
#   'in',
#   'pain',
#   'is',
#   'just',
#   'an',
#   'exampl',
#   'of',
#   'how',
#   'strong',
#   'you',
#   'are',
#   'as',
#   'a',
#   'personð',
#   'nightyð'],
#  [],
#  ['mentalhealth'],
#  ['weekend'],
#  ['thank', 'posit'],
#  ['cssday'],
#  ['bihday', 'mom', 'fondant', 'pumpkin', 'chocol', 'delici', 'beauti', 'amaz'],
#  ['bigbang', 'babi'],
#  ['tgifriday', 'goodvibesonli', 'becauseimhappi', 'smilemor'],
#  ['letsgo', 'agent', 'tooeasi', 'dlc', 'gamingforeveryon'],
#  ['tissu'],
#  [],
#  ['fowoh', 'goldenretriev', 'lcck9comfodog', 'workingdog'],
#  [],
#  ['edc', 'music', 'musiclif', 'edm', 'danc', 'girlsâ'],
#  ['funni', 'humankind', 'news', 'bad', 'good', 'future'],
#  [],
#  [],
#  ['wish', 'dad', 'father', 'day', 'rock'],
#  ['abrahamhick', 'lawofattract', 'healthi', 'heal', 'joytrain'],
#  ['model'],
#  [],
#  ['smile'],
#  ['success', 'quot'],
#  [],
#  ['friends', 'sweden', 'reunion', 'grateful', 'lov'],
#  ['pizzaslice',
#   'pizzaslice2',
#   'aoyama',
#   'pizza',
#   'yummy',
#   'delicia',
#   'goodtimeswithgoâ'],
#  ['beer', 'craftbee', 'dog', 'malinoislov', 'malinoi', 'passion', 'friend'],
#  ['i_am', 'posit', 'affirm'],
#  ['fatherã', 'day', 'dad', 'skinni', 'and', 'singl'],
#  [],
#  ['cleveland', 'home', 'calm'],
#  ['gun', 'mentalil', 'gang', 'orlando'],
#  [],
#  ['bless', 'lipstick', 'makeup', 'fun', 'grate', 'share'],
#  [],
#  [],
#  [],
#  ['saturday', 'morning', 'thetrust', 'comus', 'indi'],
#  ['father', 'day'],
#  ['good'],
#  [],
#  ['orlando', 'vengeanc'],
#  ['live_long'],
#  ['graduat', 'mechtechplumb', 'futureplumb', 'proudmama'],
#  ['model'],
#  ['orlando', 'christinagrimmi', 'prayer'],
#  ['innovative_n'],
#  ['social', 'analyt', 'instalik', 'tbt', 'yoga', 'summer', 'fun'],
#  [],
#  ['newflat'],
#  ['love', 'chees', 'shotermlongdist'],
#  ['friendship'],
#  ['poor', 'sin', 'jesu', 'faith', 'believ', 'wisdom'],
#  ['lovequot'],
#  ['posit'],
#  ['orlandoshoot', 'gunviol'],
#  ['zaz', 'umbrela'],
#  [],
#  ['tcashowroom'],
#  [],
#  ['relax', 'positivevib', 'california', 'cakesbytheocean'],
#  ['eur', 'blog', 'silver', 'gold', 'forex'],
#  ['brokedonald', 'lyindon'],
#  ['friday', 'fridayfeel', 'friyay', 'goodweek', 'client', 'hairâ'],
#  [],
#  [],
#  ['selfi', 'myfriend', 'loveh', 'giannena', 'smile', 'thecomeback'],
#  [],
#  [],
#  ['burnsurvivor', 'dolbf', 'motiv', 'motiv'],
#  ['greatfultogod', 'beendoinggreat', 'selfi'],
#  ['dog'],
#  ['nosie', 'year', 'wrc', 'rallypoland'],
#  ['music', 'edinburgh', 'scotland', 'band', 'musicvideo'],
#  ['pulseshoot'],
#  [],
#  ['33'],
#  ['drakeandjosh'],
#  [],
#  ['openrp', 'bore'],
#  ['manchest', 'gin'],
#  ['trailn2v3'],
#  ['kikid', 'miabbook'],
#  ['inspir', 'lyf', 'baba'],
#  ['beauti', 'homeown'],
#  [],
#  [],
#  ['brickingit'],
#  [],
#  [],
#  [],
#  [],
#  ['shop', 'cool', 'home', 'fun'],
#  ['doubledown', 'veganbeerfest', 'vegan'],
#  [],
#  ['bjmckenzi', 'born2win', 'bjmuzic'],
#  [],
#  ['jaibalayya'],
#  ['kingsland', 'highlandreserv', 'hous', 'famili', 'build', 'ourhomeâ'],
#  [],
#  ['decor'],
#  ['soldâ'],
#  [],
#  ['marb', 'euro2016', 'depress', 'bringbackhappi'],
#  [],
#  ['gdragon',
#   'kwonjiyong',
#   'jiyong',
#   'vip',
#   'bigbang',
#   'handsom',
#   'cute',
#   'loveâ'],
#  [],
#  [],
#  [],
#  ['develop', 'python'],
#  ['womenareamaz', 'induoev', 'superwomen', 'follow', 'dowhatyoulov'],
#  [],
#  ['oitnb', 'myfavorit', 'season4', 'weekendplan'],
#  ['christinagrimmi', 'loss', 'rip', 'miss', 'fan', 'foreverinourhea'],
#  ['sundayrewind', 'hongkong', 'travel', 'ladi', 'lawyerâ'],
#  ['inger',
#   'followm',
#   'follow',
#   'follow4follow',
#   'beach',
#   'pool',
#   'relax',
#   'enjoy',
#   'coupleâ'],
#  ['family', 'freeevent', 'festival', 'food', 'stal'],
#  ['awesom', 'gopro', 'mount'],
#  ['booktim', 'muchlov'],
#  ['summereven', 'patioweath'],
#  [],
#  ['imi'],
#  ['model'],
#  ['theshallow'],
#  ['offici', 'poster', 'poalorigin', 'summer'],
#  ['wwdc', 'wwdc2016'],
#  [],
#  ['blessed', 'thank'],
#  ['sundaymorn', 'sunday', 'peac', 'love'],
#  ['quot', 'latenight'],
#  [],
#  ['selflov',
#   'love',
#   'ilovem',
#   'quot',
#   'quot',
#   'quoteoftheday',
#   'happi',
#   'life',
#   'wisdom',
#   'wordsofwisdom'],
#  ['boy', 'father', 'sweet', 'love', 'memori'],
#  [],
#  ['life',
#   'impoant',
#   'human',
#   'spirit',
#   'truth',
#   'love',
#   'give',
#   'spiritu',
#   'thinkbigsundaywithmarshað'],
#  ['father'],
#  [],
#  [],
#  [],
#  ['wed', 'love'],
#  ['friday'],
#  [],
#  ['fun', 'eatâ'],
#  [],
#  ['blogger', 'vloggerâ'],
#  ['edinburgh'],
#  [],
#  [],
#  ['passthecourvoisi'],
#  ['rescuepup', 'rexi', 'pupsofsg', 'suicidegirl', 'beauti', 'puppylov'],
#  ['tech', 'augment', 'futur', 'mobil'],
#  [],
#  [],
#  ['hellosunday', 'beauti', 'sunday', 'sundayfunday'],
#  [],
#  ['nzd', 'blog', 'silver', 'gold', 'forex'],
#  [],
#  ['bihday', 'rip', 'tupacâ'],
#  [],
#  ['motionpost', 'mupparimanam', 'nervou'],
#  [],
#  ['compleanno', 'toa', 'cake', 'famili', 'selfi', 'smile', 'girl', 'summerâ'],
#  ['anim', 'anime', 'tags', 'anime', 'fana'],
#  ['memori', '2year', 'lotstocom', 'love'],
#  ['spoonieproblem'],
#  ['bless'],
#  ['eur', 'blog', 'silver', 'gold', 'forex'],
#  ['ngitingtagumpay'],
#  ['welcomeludovica'],
#  ['cloudchas'],
#  ['vlicob',
#   'xoxo',
#   'love',
#   'grace',
#   'amen',
#   'share',
#   'passion',
#   'church',
#   'lifeâ'],
#  ['job', 'jobsearch', 'chandigarh'],
#  ['restaur', 'eatallyoucan'],
#  ['nervou', 'gameofthron'],
#  [],
#  ['intruduceyourself'],
#  ['ramadan', 'ramadankareem'],
#  [],
#  ['success', 'growth', 'balanc', 'optim'],
#  [],
#  ['thank', 'posit'],
#  [],
#  ['beach', 'loveit'],
#  [],
#  ['tgif', 'gamedev', 'indiedev', 'indiegamedev', 'squad'],
#  [],
#  ['goodmorn'],
#  [],
#  ['yum', 'thespicesndteaexchang', 'healthyâ'],
#  ['followm'],
#  ['love',
#   'like',
#   'live',
#   'life',
#   'enjoy',
#   'healthi',
#   'sun',
#   'tan',
#   'bikini',
#   'summerâ'],
#  ['teenageson', 'fathersday'],
#  [],
#  [],
#  ['getalif'],
#  [],
#  ['nothappi'],
#  ['closeencount', 'fatkind', 'fatkid', 'dese', 'sick', 'tire', 'maybemono'],
#  ['gymmorgon', 'gym', 'morn', 'strength', 'energi', 'train'],
#  [],
#  ['truthseek', 'empower', 'selfimprov', 'heal', 'ihearadio'],
#  ['deletetweet'],
#  ['view',
#   'oregon',
#   'poland',
#   'usa',
#   'unitedst',
#   'holiday',
#   'produc',
#   'houseâ'],
#  ['vote', 'share', 'you', 'smile', 'poll'],
#  [],
#  ['travelwis', 'europe2016', 'london', 'pari'],
#  ['thank', 'posit'],
#  [],
#  [],
#  ['smile', 'pearli'],
#  ['gentleman'],
#  ['love'],
#  [],
#  [],
#  ['2016neotour'],
#  [],
#  ['movinghouâ'],
#  ['music'],
#  ['barbequ', 'hostel', 'summer', 'surf', 'kitesurf', 'wave', 'fun', 'holiday'],
#  ['cnnelect', 'onpoint'],
#  ['masterkeyexperi'],
#  ['crazi',
#   'fashion',
#   'fun',
#   'color',
#   'gown',
#   'fashiondesign',
#   'design',
#   'illustrationâ'],
#  ['fit', 'fresh'],
#  [],
#  [],
#  [],
#  ['liber'],
#  [],
#  ['newyear', 'newbless', 'thank', 'grate'],
#  ['cymruambyth'],
#  ['teamandr', 'idontcareifhesbritish'],
#  ['hurryup'],
#  ['happi', 'realtimechem', 'chemistri', 'educ'],
#  ['sunday',
#   'weekend',
#   'drink',
#   'night',
#   'view',
#   'summer',
#   'fullmoon',
#   'dtla',
#   'fun'],
#  [],
#  ['euro2016'],
#  ['windows10', 'browser', 'lumia950xl'],
#  ['lighttherapi', 'depression', 'altwaystoh', 'healthi', 'happi'],
#  ['bless', 'thank', 'optimist', 'posit', 'faith', 'strong', 'motiv'],
#  ['littlewond'],
#  [],
#  [],
#  ['atlanta'],
#  ['balconyview',
#   'brunch',
#   'sundaybrunch',
#   'sunday',
#   'istanbul',
#   'love',
#   'girl',
#   'instalikeâ'],
#  ['columbu', 'mbb', 'mygrind', 'mrbaileybabi', 'tshiâ'],
#  ['william', 'blog', 'silver'],
#  [],
#  [],
#  ['kid', 'destruct'],
#  ['helpm', 'imnotusetothi', 'perfecttim', 'weekend'],
#  ['cantwait', 'latvia', 'hereicom', 'midsumm', 'familli', 'friendsâ'],
#  ['love', 'women'],
#  ['educationfest'],
#  [],
#  ['reviv', 'sunris', 'rebelhea', 'morn', 'pielcanela'],
#  [],
#  ['lighttherapi', 'depression', 'altwaystoh', 'healthi', 'happi'],
#  ['peac', 'inspir'],
#  ['motiv'],
#  ['teammacb', 'fitmom', 'fitlifeâ'],
#  [],
#  ['tranni', 'ladyboy', 'asianladyboy', 'thailand', 'usa', 'lasvegasâ'],
#  [],
#  [],
#  ['johnxsafari', 'eastcapehunt', 'famili', 'proud', 'africa'],
#  ['selfi', 'freetim', 'smile', 'instaviã', 'sonrisa', 'ust'],
#  ['loop', 'shop', 'vine'],
#  ['coverlov', 'bookporn'],
#  ['euref'],
#  ['destini'],
#  ['i_am', 'posit', 'affirm'],
#  ['heal', 'healthi', 'idwp', 'joytrain'],
#  ['run', 'park', 'summer', 'exercis', 'fit', 'helthi'],
#  ['hangingon'],
#  [],
#  [],
#  [],
#  ['hate', 'game', 'survey'],
#  ['lighttherapi', 'depression', 'altwaystoh', 'healthi', 'happi'],
#  ['smile', 'laugh', 'breathe', 'lov'],
#  ...]

# %%
HT_regular = sum(HT_regular, [])
len(HT_regular)
# Out:
# 70180

# %%
HT_negative = sum(HT_negative, [])
HT_negative
# Out:
# ['cnn',
#  'michigan',
#  'tcot',
#  'australia',
#  'opkillingbay',
#  'seashepherd',
#  'helpcovedolphin',
#  'thecov',
#  'helpcovedolphin',
#  'neverump',
#  'xenophobia',
#  'love',
#  'peac',
#  'race',
#  'ident',
#  'medâ',
#  'altright',
#  'whitesupremaci',
#  'linguist',
#  'race',
#  'power',
#  'raciolinguist',
#  'brexit',
#  'peopl',
#  'trump',
#  'republican',
#  'michelleobama',
#  'knick',
#  'golfâ',
#  'jewishsupremacist',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'trash',
#  'hate',
#  'â',
#  'stereotyp',
#  'prejudic',
#  'hope',
#  'hate',
#  'conflictâ',
#  'pol',
#  'bluelivesmatt',
#  'draintheswamp',
#  'ferguson',
#  '2016',
#  'antisemit',
#  'hocoschool',
#  'columbiamd',
#  'hocomd',
#  'nazi',
#  'hatred',
#  'bigotri',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'p21',
#  'fyi',
#  'tcot',
#  'topoli',
#  'blacklivesmatt',
#  'ushistori',
#  'eugen',
#  'biher',
#  'bigotri',
#  'altright',
#  'potu',
#  'theresist',
#  'crime',
#  'officerâ',
#  'black',
#  'retweet',
#  'tampa',
#  'miamiâ',
#  'allahsoil',
#  'prais',
#  'cleveland',
#  'rnc',
#  'white',
#  'tamirric',
#  'rip',
#  'bigot',
#  'blacklivesmatt',
#  'feminismiscanc',
#  'feminismisterror',
#  'feminismmuktbharat',
#  'malevot',
#  'prowar',
#  'anti',
#  'islamic',
#  'homophobic',
#  'rapist',
#  'hypocrit',
#  'latesnew',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'trump',
#  'dumptrump',
#  'lifelesson',
#  'blogpost',
#  'whitepeopl',
#  'respectâ',
#  'fakenewsal',
#  'hateâ',
#  'trump',
#  'hate',
#  'putin',
#  'trump',
#  'starspangledbann',
#  'slaveri',
#  'apaheid',
#  'usa',
#  'social',
#  'media',
#  'aand',
#  'eod',
#  'trump',
#  'vile',
#  'bigot',
#  'hi',
#  'surrog',
#  'carlpaladino',
#  'endhateâ',
#  'allahsoil',
#  'discrimin',
#  'endthen',
#  'misogyny',
#  'homophobia',
#  'bigotri',
#  'rushlimbaugh',
#  'trumpusa',
#  'homophob',
#  'misogynist',
#  'sjw',
#  'hope',
#  'newyear',
#  'endof2016',
#  'tedtalk',
#  'tedatibm',
#  'cspan',
#  'peopl',
#  'trump',
#  'republican',
#  'opinion',
#  'degrad',
#  'discrimin',
#  'violenc',
#  'stoprac',
#  'allahsoil',
#  'isi',
#  'islam',
#  '2016in4world',
#  '2016in4word',
#  'terrorist',
#  'gwot',
#  'tuckercarlson',
#  'oppress',
#  'oppressors',
#  'privileg',
#  'space',
#  'ivankatrump',
#  'fake',
#  'adamsaleh',
#  'raâ',
#  'zionazi',
#  'lbgt',
#  'trump',
#  'barackobama',
#  'michelleobama',
#  'quebec',
#  'humanright',
#  'justic',
#  'berlin',
#  'returnmyvinyl',
#  'chrismukkah',
#  'keyboard',
#  'bigot',
#  'misogynist',
#  'keepyoureyesontheprize',
#  'black',
#  'africanamerican',
#  'repar',
#  'potu',
#  'trump',
#  'israel',
#  'happynewyear',
#  'decolon',
#  'america',
#  'treasonoustrump',
#  'whiteisi',
#  'terrorism',
#  'ellen',
#  'kimburrel',
#  'newyear',
#  'prez',
#  'destruction',
#  'commercials',
#  'poopin',
#  'shuckin',
#  'democraticpay',
#  'hitler',
#  'traitor',
#  'trump',
#  'liber',
#  'birdsofafeath',
#  'resist',
#  'versace',
#  'rich',
#  'white',
#  'snob',
#  'tcot',
#  'tpc',
#  'joke',
#  '2016',
#  'feminismiscanc',
#  'feminismisterror',
#  'feminismmuktbharat',
#  'malevot',
#  'tyler',
#  'perri',
#  'claim',
#  'revers',
#  'criticsâ',
#  'hypocrit',
#  'liar',
#  'inhumaneâ',
#  'psa',
#  'sikh',
#  'templ',
#  'calgary',
#  'wso',
#  'allahsoil',
#  'emirati',
#  '2016in4word',
#  'mentalhealth',
#  'firstnations',
#  'thirdworldcanada',
#  'democraticpay',
#  'blm',
#  'chicago',
#  'detroit',
#  'innâ',
#  'new',
#  'phillysuppophilli',
#  'allahsoil',
#  'illeg',
#  'criminals',
#  'commonsense',
#  'deviant',
#  'barackobama',
#  'feminist',
#  'reproductiveright',
#  'bihcontrol',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'hillaryclinton',
#  'homophob',
#  'misogynist',
#  'newyearseve',
#  'resolut',
#  'domesticviol',
#  'love',
#  'japan',
#  'fascism',
#  'guardian',
#  'nytim',
#  'bbc',
#  'afp',
#  'rsf',
#  'altright',
#  'maga',
#  'fear',
#  'black',
#  'retweet',
#  'tampa',
#  'miamiâ',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'yehtut',
#  'rohingya',
#  'dvbmultimediagroup',
#  'yehtut',
#  'gop',
#  'hrc',
#  'popularvot',
#  'ca',
#  'trump',
#  '2017in3wordsâ',
#  'electoralcolleg',
#  'trump',
#  'notmypresid',
#  'newswith',
#  'genocid',
#  'lgbtq',
#  'arab',
#  'god',
#  'cnn',
#  'foxnew',
#  'christian',
#  'conserv',
#  'christ',
#  'censorship',
#  'freethenippl',
#  'bulli',
#  'allahsoil',
#  'grandmoth',
#  'grandson',
#  'exist',
#  'alreadi',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'blackwomen',
#  'asianmen',
#  'datingapp',
#  'antirac',
#  'seashepherd',
#  'deplorabal',
#  'whitesheet',
#  'inbr',
#  'canuck',
#  'oiler',
#  'american',
#  'bigotri',
#  'hatr',
#  'homophobic',
#  'warmonger',
#  'worlddang',
#  'trumpsamerica',
#  'hate',
#  'america',
#  'controversi',
#  'equal',
#  'kaepernick',
#  'nationalanthem',
#  'laurenduca',
#  'hispan',
#  'black',
#  'asian',
#  'cnnâ',
#  'hispan',
#  'retweet',
#  'boricua',
#  'miamiâ',
#  'hatred',
#  'xenophobia',
#  'islamophobia',
#  'antisemitism',
#  'war',
#  '2017',
#  'antirac',
#  'seashepherd',
#  'polit',
#  'relationship',
#  'newâ',
#  'santa',
#  'obama',
#  'soro',
#  'allahsoil',
#  'teambt',
#  'teamsuperjuniorâ',
#  'blackonblack',
#  'ris2016',
#  'antiblack',
#  'dogwhistl',
#  'blacklivesmatt',
#  'hamzayusuf',
#  'zionazi',
#  'antisemt',
#  'womenwednesdayâ',
#  'dystopian',
#  'radicalis',
#  'reveng',
#  'preorder',
#  '99c',
#  'fascism',
#  'nazi',
#  'altright',
#  'richardspenc',
#  'trumpism',
#  'dâ',
#  'trump',
#  'michelleobama',
#  'womensmarch',
#  'women',
#  'predatorâ',
#  'sameshitnewyear',
#  'corrupt',
#  'trump',
#  'terrorattack',
#  'fundament',
#  'violenc',
#  'isi',
#  'crisi',
#  'hatr',
#  'murder',
#  'terror',
#  'bigot',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'america',
#  'american',
#  'altright',
#  'whitesupremaci',
#  'new',
#  'phillysuppophilli',
#  'democrat',
#  'europ',
#  'nyt',
#  'libcrib',
#  'uniteblu',
#  'fascism',
#  'trump',
#  'fear',
#  'ignor',
#  'hate',
#  'misogyni',
#  'aloha',
#  'fascism',
#  'warsforoil',
#  'antirac',
#  'seashepherd',
#  'theresamay',
#  'brexit',
#  'remain',
#  'nycâ',
#  'assault',
#  'womenonli',
#  'forher',
#  '2017',
#  'newyear',
#  'resolut',
#  'womenissuesâ',
#  'texa',
#  'justicereform',
#  'maddow',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'chepstow',
#  'gwent',
#  'wale',
#  'cymru',
#  'familycircu',
#  'chriâ',
#  'christian',
#  'retweetâ',
#  'trump',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'childfreeâ',
#  'economicapahied',
#  'hatespeech',
#  'asshol',
#  'rapist',
#  'pedophil',
#  'evil',
#  'satanist',
#  'stop',
#  'joke',
#  '2016',
#  'feminismiscanc',
#  'feminismisterror',
#  'feminismmuktbharat',
#  'malevot',
#  'corruptgop',
#  'nyc',
#  'newyork',
#  'women',
#  'men',
#  'bigot',
#  'carlpalladino',
#  'michelleobama',
#  'allahsoil',
#  'politicalmillenni',
#  'letstalkabout',
#  'climatechang',
#  'educationâ',
#  'notmypresidnet',
#  'american',
#  'bigotri',
#  'hatr',
#  'america',
#  'controversi',
#  'equal',
#  'kaepernick',
#  'nationalaâ',
#  'isra',
#  'jewish',
#  'judea',
#  'samaria',
#  'gop',
#  'deplor',
#  'notfunni',
#  'swamp',
#  '20day',
#  'dem',
#  'taxpay',
#  'islamicterrorist',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'alexpasc',
#  'friend',
#  'music',
#  'falsenarr',
#  'falseequaval',
#  'podcast',
#  'gun',
#  'igmilitia',
#  'pewpewlifeâ',
#  'bigotry',
#  'antirac',
#  'seashepherd',
#  'obama',
#  'communism',
#  'islam',
#  'race',
#  'nazi',
#  'muslim',
#  'scienc',
#  'medicine',
#  'love',
#  'notmypresid',
#  'resist',
#  '2017',
#  'chang',
#  'antirac',
#  'neverump',
#  'pussygrabberinchief',
#  'idiocraci',
#  'gtfoh',
#  'crackalog',
#  'allahsoil',
#  'men',
#  'harass',
#  'verbalassault',
#  'polic',
#  'checkcash',
#  'atlanta',
#  'blackmen',
#  'profil',
#  'equal',
#  'divers',
#  'buffalo',
#  'resign',
#  'obama',
#  'carlpaladino',
#  'newyork',
#  'malvern',
#  'arkansa',
#  'nigelfarage',
#  'immigr',
#  'sulfur',
#  'trump',
#  'sisterinlaw',
#  'frustrated',
#  'idiots',
#  'mexican',
#  'lmao',
#  'mcconnel',
#  'obama',
#  'jew',
#  'libtard',
#  'truth',
#  'polic',
#  'maga',
#  'audiblechannel',
#  'sâ',
#  'trump',
#  'whitesupremaci',
#  'fakenew',
#  'america',
#  'colâ',
#  'blm',
#  'eugen',
#  'southafrica',
#  'leadership',
#  'transform',
#  'inequ',
#  'hispan',
#  'retweet',
#  'boricuaâ',
#  'theresist',
#  'resist',
#  'resist',
#  'maga',
#  'altright',
#  'raâ',
#  'sikh',
#  'templ',
#  'calgary',
#  'wso',
#  'treason',
#  'aidingenemi',
#  'fraud',
#  'coverup',
#  'benghazi',
#  'extoion17',
#  'israel',
#  'notmypr',
#  'wtf2016',
#  'neverump',
#  'unpresid',
#  'bigot',
#  'allahsoil',
#  'teambtsâ',
#  'carl',
#  'paladino',
#  'michel',
#  'obama',
#  'live',
#  'gorilla',
#  'resign',
#  'resign',
#  'stop',
#  'blm',
#  'wiunion',
#  'peopl',
#  'trump',
#  'republican',
#  'racialequ',
#  'hrc',
#  'pig',
#  'trump',
#  'adulteri',
#  'incest',
#  'pedophilia',
#  'bigotri',
#  'hate',
#  'deceit',
#  'maga',
#  'notmypresid',
#  'crybulli',
#  'snowflak',
#  'diversity',
#  'humanright',
#  'ban',
#  'say',
#  'cloth',
#  'allahsoil',
#  'whitenationalist',
#  'notmypresid',
#  'fucktrump',
#  'lostpopularvot',
#  'americadoesntwanty',
#  'bigot',
#  'theresist',
#  'resist',
#  'resist',
#  'maga',
#  'altright',
#  'dt',
#  'trump',
#  'spain',
#  'liberals',
#  'misogynist',
#  'lgbti',
#  'poc',
#  'lgbti',
#  'putinschoic',
#  'stoprac',
#  'boycott',
#  'xenophobia',
#  'rainbow',
#  'divers',
#  'trump',
#  'obama',
#  'christmasev',
#  'trc',
#  'indignen',
#  'nazi',
#  'american',
#  'bigotri',
#  'hatr',
#  'altright',
#  'feminist',
#  'muslim',
#  'femin',
#  'equal',
#  'everyon',
#  'men',
#  'women',
#  'thegreenpalmcottag',
#  'plettenburgbay',
#  'westerncap',
#  'truth',
#  'malevot',
#  'conserv',
#  'punk',
#  'hypocriteâ',
#  'bluelivesmatt',
#  'allahsoil',
#  'manipur',
#  'ndtv',
#  'timenow',
#  'samachar',
#  'zeenew',
#  'dordarshan',
#  'genocid',
#  'whitepeopl',
#  'hawaii',
#  'jlaw',
#  'disrespect',
#  'fakenew',
#  'fakenewsmedia',
#  'returningcitizen',
#  'race',
#  'ethnocentr',
#  'altright',
#  'pegida',
#  'revolut',
#  'race',
#  'intersection',
#  'languag',
#  'polit',
#  'educationâ',
#  'corporateb',
#  'boycottjcpenney',
#  'corrupt',
#  'xenophobia',
#  'islamophobia',
#  'homophobia',
#  'resist',
#  'trump',
#  'leftist',
#  'christian',
#  'christianity',
#  'adamitv',
#  'prejudic',
#  'parent',
#  'russia',
#  'trump',
#  'tiesto',
#  'whiteamerica',
#  'gop',
#  'communism',
#  'spiritu',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'allahsoil',
#  'emirati',
#  '2016in4wordâ',
#  'twitteâ',
#  'allahsoil',
#  '2016in4word',
#  'islamâ',
#  'notmypresid',
#  'fibromyalgia',
#  'survivor',
#  'childrape',
#  'ass',
#  'hole',
#  'head',
#  'big',
#  'brain',
#  'hea',
#  'love',
#  'truth',
#  'kind',
#  'peac',
#  'compassâ',
#  'black',
#  'retweet',
#  'tampa',
#  'miamiâ',
#  'talkradio',
#  'treason',
#  'trump',
#  'makeamericagreatagain',
#  'philandocastil',
#  'trump',
#  'economi',
#  'hype',
#  'fool',
#  'idiot',
#  'polit',
#  'media',
#  'blm',
#  'brexit',
#  'trump',
#  'leadership',
#  'black',
#  'retweet',
#  'tampa',
#  'miamiâ',
#  'whiteslav',
#  'whiteslaveri',
#  'venezuela',
#  'hispan',
#  'retweet',
#  'boricuaâ',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'new',
#  'phillysuppophilli',
#  'antirac',
#  'seashepherd',
#  'rupemurdoch',
#  'master',
#  'libtard',
#  'sjw',
#  'liber',
#  'polit',
#  'depoat',
#  'putinschoic',
#  'putinspuppet',
#  'retweetâ',
#  'stone',
#  'kill',
#  'quebec',
#  'crimin',
#  'podcast',
#  'nazi',
#  'swastika',
#  'ebay',
#  'trump',
#  'donaldtrump',
#  'republic',
#  'whitepow',
#  'pig',
#  'liar',
#  'dzang',
#  'capetown',
#  'movi',
#  'indian',
#  'challeng',
#  'rewrit',
#  'trumpsamerica',
#  'feel',
#  'empowerd',
#  'fowoh',
#  'caturday',
#  'thank',
#  'dead',
#  'white',
#  'dude',
#  'europe',
#  'nigga',
#  'list',
#  'rapechucktoddâ',
#  'iqg',
#  'â',
#  'peopl',
#  'trump',
#  'republican',
#  'allahsoil',
#  'teambt',
#  'teamsuperjunior',
#  'bluelivesmatt',
#  'woke',
#  'manspread',
#  'ifyourenotwhiteyourenotracist',
#  'seashepherd',
#  'antirac',
#  'bigot',
#  'doublestanâ',
#  'kentucki',
#  'jcpenni',
#  'mexican',
#  'bitchesbelik',
#  'cleveland',
#  'ohio',
#  'white',
#  'brexit',
#  'littleengland',
#  'mustread',
#  'educ',
#  'stereotyp',
#  'bigot',
#  'trumpproofamerica',
#  'sikh',
#  'templ',
#  'calgary',
#  'wso',
#  'uspoli',
#  'potter',
#  'greed',
#  'li',
#  'misogyny',
#  'fail',
#  'bigot',
#  'trump',
#  'uselections2016',
#  'leadership',
#  'polit',
#  'brexit',
#  'blm',
#  'climatechang',
#  'fascism',
#  'antiegalitarianism',
#  'narcissism',
#  'trump',
#  'miami',
#  'policebrut',
#  'newswith',
#  'trump',
#  'trump',
#  'sandnigg',
#  'uskkk',
#  'msm',
#  'media',
#  'crazybengiefbps',
#  'new',
#  'phillysuppophilli',
#  'buzzfeed',
#  'manhat',
#  'shot',
#  'disparo',
#  'trompa',
#  'trumpa',
#  'migitorio',
#  'entretei',
#  'hatecrim',
#  'sikh',
#  'calgari',
#  'patriotwatch',
#  'auspol',
#  'rwnj',
#  'upf',
#  'cult',
#  'cultism',
#  'project',
#  'springst',
#  'straya',
#  'misogyni',
#  'left',
#  'hispan',
#  'retweet',
#  'boricuaâ',
#  'arrog',
#  'abus',
#  'discrimin',
#  'dutch',
#  'drs',
#  'nigger',
#  'pattismith',
#  'in2017iwantto',
#  'whiteprivilege',
#  'privilege',
#  'whiteâ',
#  'tcot',
#  'femin',
#  'sjw',
#  'sjwlogic',
#  '2017',
#  'joy',
#  'love',
#  'deaf',
#  'rethinkdiscipline',
#  'ableism',
#  'audism',
#  'stpp',
#  'massincarcer',
#  'deafinprison',
#  'decriminalizâ',
#  'help',
#  'resign',
#  'liber',
#  'trump',
#  'racebait',
#  'jacobmarley',
#  'potter',
#  'misogynist',
#  'narrow',
#  'epicâ',
#  'alllivesmatt',
#  'unbornlivesmatt',
#  'newyearsev',
#  'islamophobia',
#  'femin',
#  'culturalenrich',
#  'race',
#  'trump',
#  'childish',
#  'paisanhack',
#  'neglig',
#  ...]

# %%
a = nltk.FreqDist(HT_regular)
d = pd.DataFrame({'Hashtag': list(a.keys()), 'Count': list(a.values()) })
d = d.nlargest(columns="Count", n=20)
plt.figure(figsize =(16, 5))
ax = sns.barplot(data=d, x ="Hashtag", y="Count")
ax.set(ylabel = 'Count')
plt.show()

# %%
a = nltk.FreqDist(HT_negative)
d = pd.DataFrame({'Hashtag': list(a.keys()), 'Count': list(a.values()) })
d = d.nlargest(columns="Count", n=20)
plt.figure(figsize =(16, 5))
ax = sns.barplot(data=d, x ="Hashtag", y="Count")
ax.set(ylabel = 'Count')
plt.show()
